# %% [markdown]
# # Global Power Plant Database
#
# ## Project Description
#
# The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 35,000 power plants from 167 countries and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.
# Key attributes of the database
#
# The database includes the following indicators:
#
# -	`country` (text): 3 character country code corresponding to the ISO 3166-1 alpha-3 specification [5]
# -	`country_long` (text): longer form of the country designation
# -    `name` (text): name or title of the power plant, generally in Romanized form
# -	`gppd_idnr` (text): 10 or 12 character identifier for the power plant
# -	`capacity_mw` (number): electrical generating capacity in megawatts
# -	`latitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
# -	`longitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
# -	`primary_fuel` (text): energy source used in primary electricity generation or export
# -	`other_fuel1` (text): energy source used in electricity generation or export
# -	`other_fuel2` (text): energy source used in electricity generation or export
# -	`other_fuel3` (text): energy source used in electricity generation or export
# -	 `commissioning_year` (number): year of plant operation, weighted by unit-capacity when data is available
# -	`owner` (text): majority shareholder of the power plant, generally in Romanized form
# -	`source` (text): entity reporting the data; could be an organization, report, or document, generally in Romanized form
# -	`url` (text): web document corresponding to the `source` field
# -	`geolocation_source` (text): attribution for geolocation information
# -	`wepp_id` (text): a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
# -	`year_of_capacity_data` (number): year the capacity information was reported
# -	`generation_gwh_2013` (number): electricity generation in gigawatt-hours reported for the year 2013
# -	`generation_gwh_2014` (number): electricity generation in gigawatt-hours reported for the year 2014
# -	`generation_gwh_2015` (number): electricity generation in gigawatt-hours reported for the year 2015
# -	`generation_gwh_2016` (number): electricity generation in gigawatt-hours reported for the year 2016
# -	`generation_gwh_2017` (number): electricity generation in gigawatt-hours reported for the year 2017
# -	`generation_gwh_2018` (number): electricity generation in gigawatt-hours reported for the year 2018
# -	`generation_gwh_2019` (number): electricity generation in gigawatt-hours reported for the year 2019
# -	`generation_data_source` (text): attribution for the reported generation information
# -	`estimated_generation_gwh_2013` (number): estimated electricity generation in gigawatt-hours for the year 2013
# -	`estimated_generation_gwh_2014` (number): estimated electricity generation in gigawatt-hours for the year 2014
# -	`estimated_generation_gwh_2015` (number): estimated electricity generation in gigawatt-hours for the year 2015
# -	`estimated_generation_gwh_2016` (number): estimated electricity generation in gigawatt-hours for the year 2016
# -	`estimated_generation_gwh_2017` (number): estimated electricity generation in gigawatt-hours for the year 2017
# -	`estimated_generation_note_2013` (text): label of the model/method used to estimate generation for the year 2013
# -	`estimated_generation_note_2014` (text): label of the model/method used to estimate generation for the year 2014
# -	`estimated_generation_note_2015` (text): label of the model/method used to estimate generation for the year 2015
# -	`estimated_generation_note_2016` (text): label of the model/method used to estimate generation for the year 2016
# -	`estimated_generation_note_2017` (text): label of the model/method used to estimate generation for the year 2017
#
# ### Fuel Type Aggregation
#
# We define the "Fuel Type" attribute of our database based on common fuel categories.
#
# Prediction :   Make two prediction  1) Primary Fuel    2) capacity_mw
#
#
# ### Dataset Link-
# -	https://github.com/wri/global-power-plant-database/blob/master/source_databases_csv/database_IND.csv

# %%
# Importing important librabry
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading dataset

# %%
df=pd.read_csv("https://raw.githubusercontent.com/wri/global-power-plant-database/master/source_databases_csv/database_IND.csv")
pd.set_option('display.max_columns', None)
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  other_fuel3  \
# 0   28.1839    73.2407        Solar         NaN         NaN          NaN
# 1   24.7663    74.6090         Coal         NaN         NaN          NaN
# 2   21.9038    69.3732         Wind         NaN         NaN          NaN
# 3   23.8712    91.3602          Gas         NaN         NaN          NaN
# 4   21.9603    82.4091         Coal         Oil         NaN          NaN
#
#    commissioning_year                 owner  \
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## Statical Analysis

# %%
df.shape
# Out:
# (907, 27)

# %% [markdown]
# There are 907 rows as 27 column in the dataset

# %%
df.isna().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
# Except country, country_long, name, gppd_idnr, capacity_mw ,source, url,primary_fuel all columns have  null values

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %% [markdown]
# we have float64(15), object(12) and it uses memory usage: 191.4+ KB form above code we can see that we have null values in many columns

# %%
df.nunique().to_frame()
# Out:
#                             0
# country                     1
# country_long                1
# name                      907
# gppd_idnr                 907
# capacity_mw               361
# latitude                  836
# longitude                 827
# primary_fuel                8
# other_fuel1                 3
# other_fuel2                 1
# other_fuel3                 0
# commissioning_year         73
# owner                     280
# source                    191
# url                       304
# geolocation_source          3
# wepp_id                     0
# year_of_capacity_data       1
# generation_gwh_2013         0
# generation_gwh_2014       371
# generation_gwh_2015       396
# generation_gwh_2016       403
# generation_gwh_2017       408
# generation_gwh_2018       410
# generation_gwh_2019         0
# generation_data_source      1
# estimated_generation_gwh    0

# %% [markdown]
# From above code wee can see that generation_gwh_2019,generation_gwh_2019,generation_gwh_2013 have no values and generation_data_source,year_of_capacity_data,other_fuel2,country_long, and country have only 1 value

# %% [markdown]
# ### Feature Engineering

# %%
# Droping the columns with high null values
df1=df.drop(['country','country_long','name','other_fuel3','other_fuel2','wepp_id','generation_gwh_2013','generation_gwh_2019','estimated_generation_gwh'],axis=1)

# %%
df1.shape
# Out:
# (907, 18)

# %% [markdown]
# We have dropped 9 columns with high null values and left with 18 columns.

# %%
df1.isna().sum().to_frame()
# Out:
#                           0
# gppd_idnr                 0
# capacity_mw               0
# latitude                 46
# longitude                46
# primary_fuel              0
# other_fuel1             709
# commissioning_year      380
# owner                   565
# source                    0
# url                       0
# geolocation_source       19
# year_of_capacity_data   388
# generation_gwh_2014     509
# generation_gwh_2015     485
# generation_gwh_2016     473
# generation_gwh_2017     467
# generation_gwh_2018     459
# generation_data_source  458

# %% [markdown]
# We have many columns with null value left but we can't drop all of them as we need data to build model

# %%
df1.nunique().to_frame()
# Out:
#                           0
# gppd_idnr               907
# capacity_mw             361
# latitude                836
# longitude               827
# primary_fuel              8
# other_fuel1               3
# commissioning_year       73
# owner                   280
# source                  191
# url                     304
# geolocation_source        3
# year_of_capacity_data     1
# generation_gwh_2014     371
# generation_gwh_2015     396
# generation_gwh_2016     403
# generation_gwh_2017     408
# generation_gwh_2018     410
# generation_data_source    1

# %%
df1.head(10)
# Out:
#     gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0  WRI1020239          2.5   28.1839    73.2407        Solar         NaN
# 1  WRI1019881         98.0   24.7663    74.6090         Coal         NaN
# 2  WRI1026669         39.2   21.9038    69.3732         Wind         NaN
# 3  IND0000001        135.0   23.8712    91.3602          Gas         NaN
# 4  IND0000002       1800.0   21.9603    82.4091         Coal         Oil
# 5  IND0000003        250.0   23.7689    68.6447         Coal         Oil
# 6  IND0000004         60.0   10.4547    77.0078        Hydro         NaN
# 7  IND0000005        192.0   32.2258    77.2070        Hydro         NaN
# 8  IND0000006        290.0   16.3300    75.8863        Hydro         NaN
# 9  IND0000007        210.0   23.1642    81.6373         Coal         Oil
#
#    commissioning_year                 owner  \
# 0              2011.0           Solar Paces
# 1                 NaN  Ultratech Cement ltd
# ...

# %%
df1.primary_fuel.value_counts()
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# Value count of Primary fuel gives the detail about the fuel type highest is Coal after that we have Hydro

# %%
# we are dropping the columns with data which is not useful
df2=df1.drop(['gppd_idnr','owner','generation_data_source'],axis=1)

# %%
df2.shape
# Out:
# (907, 15)

# %% [markdown]
# We are left with 15 columns.

# %%
df2.isna().sum().to_frame()
# Out:
#                          0
# capacity_mw              0
# latitude                46
# longitude               46
# primary_fuel             0
# other_fuel1            709
# commissioning_year     380
# source                   0
# url                      0
# geolocation_source      19
# year_of_capacity_data  388
# generation_gwh_2014    509
# generation_gwh_2015    485
# generation_gwh_2016    473
# generation_gwh_2017    467
# generation_gwh_2018    459

# %%
df2.other_fuel1.unique()
# Out:
# array([nan, 'Oil', 'Cogeneration', 'Gas'], dtype=object)

# %%
df2.primary_fuel.unique()
# Out:
# array(['Solar', 'Coal', 'Wind', 'Gas', 'Hydro', 'Biomass', 'Oil',
#        'Nuclear'], dtype=object)

# %% [markdown]
# Creating new feature by combining multiple features

# %%
new_columns = ['generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018']
df2['genration_gwh_total'] = df2[new_columns].sum(axis=1)

# %%
df2.isna().sum()
# Out:
# capacity_mw                0
# latitude                  46
# longitude                 46
# primary_fuel               0
# other_fuel1              709
# commissioning_year       380
# source                     0
# url                        0
# geolocation_source        19
# year_of_capacity_data    388
# generation_gwh_2014      509
# generation_gwh_2015      485
# generation_gwh_2016      473
# generation_gwh_2017      467
# generation_gwh_2018      459
# genration_gwh_total        0
# dtype: int64

# %%
# Droping all the columns as we have combine value of all of these in new column
df2.drop(new_columns,inplace=True,axis=1)

# %%
df2.isna().sum()
# Out:
# capacity_mw                0
# latitude                  46
# longitude                 46
# primary_fuel               0
# other_fuel1              709
# commissioning_year       380
# source                     0
# url                        0
# geolocation_source        19
# year_of_capacity_data    388
# genration_gwh_total        0
# dtype: int64

# %%
df2.drop('other_fuel1',inplace=True,axis=1)

# %%
df2.shape
# Out:
# (907, 10)

# %% [markdown]
# We are left with 10 columns now

# %%
# We are using condition to filter the values which are null and 0 for these 3 columns and removing from Datafarme 
df3 = df2[~((df2['commissioning_year'].isna()) & (df2['year_of_capacity_data'].isna()) & (df2['genration_gwh_total'] == 0))]

# %%
df3.isna().sum()
# Out:
# capacity_mw               0
# latitude                 31
# longitude                31
# primary_fuel              0
# commissioning_year        0
# source                    0
# url                       0
# geolocation_source        4
# year_of_capacity_data     8
# genration_gwh_total       0
# dtype: int64

# %%
df3.shape
# Out:
# (527, 10)

# %% [markdown]
# We are left with 10 column and 527 rows

# %%
# droppinmg all the remaning null
df4=df3.dropna()

# %%
df4.shape
# Out:
# (492, 10)

# %% [markdown]
# We are left with 492 rows and 10 columns.

# %%
df4.nunique().to_frame()
# Out:
#                          0
# capacity_mw            244
# latitude               470
# longitude              469
# primary_fuel             5
# commissioning_year      71
# source                   1
# url                      1
# geolocation_source       1
# year_of_capacity_data    1
# genration_gwh_total    425

# %% [markdown]
# We have some columns with 1 unique value only

# %%
# dropping the columns whihc have only 1 unique values
df4.drop(['source','url','geolocation_source','year_of_capacity_data'],axis=1,inplace=True)

# %%
df4.shape
# Out:
# (492, 6)

# %% [markdown]
# After all the data clearing we are left with 492 rows and 6 columns for model building.

# %%
df4.describe()
# Out:
#        capacity_mw    latitude   longitude  commissioning_year  \
# count   492.000000  492.000000  492.000000          492.000000
# mean    564.601252   21.637003   79.339810         1996.884146
# std     711.130695    6.747508    5.182502           16.933102
# min       3.750000    8.169100   68.644700         1927.000000
# 25%      71.500000   16.636500   76.053200         1988.000000
# 50%     295.500000   22.240700   77.888900         2000.500000
# 75%     803.900000   26.489875   82.297175         2011.000000
# max    4760.000000   34.649000   95.408000         2018.000000
#
#        genration_gwh_total
# count           492.000000
# mean          10832.851691
# std           19503.722523
# min               0.000000
# 25%             523.489400
# 50%            2785.416625
# 75%           14530.753638
# max          156908.000000

# %% [markdown]
# From description:-
#
# 1.All column have 492 values so no missing value present.
#
# 2.The std is higher for mean Capacity_mw and genration_gwh_total.
#
# 3.All the minimum value are value and possible
#
# 4.The difference between min,25%,50%,75% and max for Capacity_mw and genration_gwh_total.
#
# 5.The mean value is greater than median (50%) for Capacity_mw and genration_gwh_total which mean data is right skewed.

# %%
# Creating a copy of original dataframe
df5=df4.copy()

# %% [markdown]
# ## Graphical Analysis

# %% [markdown]
# ### Univarient Analysis

# %%
df5.head(5)
# Out:
#    capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 3        135.0   23.8712    91.3602          Gas              2004.0
# 4       1800.0   21.9603    82.4091         Coal              2015.0
# 5        250.0   23.7689    68.6447         Coal              2005.0
# 6         60.0   10.4547    77.0078        Hydro              1970.0
# 7        192.0   32.2258    77.2070        Hydro              2010.0
#
#    genration_gwh_total
# 3          3637.554320
# 4         27859.499736
# 5          5662.606000
# 6           509.131550
# 7          3330.364500

# %%
df5.columns
# Out:
# Index(['capacity_mw', 'latitude', 'longitude', 'primary_fuel',
#        'commissioning_year', 'genration_gwh_total'],
#       dtype='object')

# %%
plt.figure(figsize=(18,18),facecolor="white")
plotnumber=1
for col in df5[['capacity_mw', 'latitude', 'longitude','commissioning_year', 'genration_gwh_total']]:
    if plotnumber<=5:
        ax=plt.subplot(2,3,plotnumber)
        sns.distplot(df5[col])
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From above graph we can see that commissioning_year and genration_gwh_total is skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df5['capacity_mw'], bins=20, edgecolor='k')
plt.title('Histogram of capacity_mw')
plt.xlabel('capacity_mw')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# From the above graph we can see that majority of the frequency is below 1000.

# %%
plt.figure(figsize=(6, 4))
plt.hist(df5['latitude'], bins=20, edgecolor='k')
plt.title('Histogram of latitude')
plt.xlabel('latitude')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# From the above graph we can see that from 20-25 we have highest frequency.

# %%
plt.figure(figsize=(6, 4))
plt.hist(df5['longitude'], bins=20, edgecolor='k')
plt.title('Histogram of longitude')
plt.xlabel('longitude')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# From the above graph we can see that from 75-80 we have highest frequency.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(df5['primary_fuel'])
plt.title('CountPlot of primary_fuel')
plt.xlabel('primary_fuel')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# From the above graph we can see that Hydro have the highest Frequency.

# %%
df5['primary_fuel'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='primary_fuel'>

# %% [markdown]
# From the above graph we can see that 47.4% of powerplant are Hydro and 1.6% is for Nuclear.

# %%
plt.figure(figsize=(6, 4))
plt.hist(df5['commissioning_year'], bins=30, edgecolor='k')
plt.title('Histogram of commissioning_year')
plt.xlabel('commissioning_year')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# We can see that as year increase the frequency is increasing

# %%
plt.figure(figsize=(6, 4))
plt.hist(df5['genration_gwh_total'], bins=20, edgecolor='k')
plt.title('Histogram of genration_gwh_total')
plt.xlabel('genration_gwh_total')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# From the above graph we can see that 0-20000 have the highest Frequency.

# %% [markdown]
# ### Bi-varient Analysis

# %%
plt.figure(figsize=(18, 18), facecolor="white")
plotnumber = 1

# Numerical features to visualize
numerical_features = ['capacity_mw', 'latitude', 'longitude', 'commissioning_year', 'genration_gwh_total']

# Iterate through the numerical features
for col in numerical_features:
    if plotnumber <= 5:
        ax = plt.subplot(2, 3, plotnumber)
        sns.histplot(data=df5, x=col, hue='primary_fuel', multiple='stack', ax=ax)
        plt.xlabel(col, fontsize=12)
    plotnumber += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# From the above graph we can see that capacity_mw have coal for almost all Capacity
# - Hydro have highest distribution near 200 MW
#
# From 20-25 degree latitude we have high frequency of coal fuel as primary fuel
#
# From 78 degree longitude we have high frequency of Hydro fuel as primary fuel
#
# From Commissioning_year 2015 we have highest Coal fuel
#
# From genration_gwh_total 4000 we have higest use of Hydro fuel.

# %% [markdown]
# ### Multivarient anayalysis

# %%
# Select a subset of numerical features for pair plot
numerical_features_subset = ['capacity_mw', 'latitude', 'longitude', 'commissioning_year', 'genration_gwh_total']

# Add the 'primary_fuel' categorical variable for color differentiation
pair_plot_data = df5[numerical_features_subset + ['primary_fuel']]

# Create a pair plot
sns.set(style="ticks")
sns.pairplot(pair_plot_data, hue="primary_fuel", diag_kind="kde")
plt.suptitle("Pair Plot of Numerical Features by Primary Fuel", y=1.02)
plt.show()

# %% [markdown]
# From the above graph we can see trends in Capacity_mw and genration_gwh_total

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()
dfo=lab_enc.fit_transform(df5['primary_fuel'])
pd.Series(dfo)
df5['primary_fuel']=dfo

# %% [markdown]
# We have encoded the fuel for further model building.

# %% [markdown]
# ## checking the outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(13,7),facecolor="white")
plotnumber=1
for col in df5:
    if plotnumber<=6:
        ax=plt.subplot(3,2,plotnumber)
        sns.boxplot(df5[col])
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# As we can see that we have outliers in most of the columns but we are not going to treat it as we have very less data left after treating null valus and as we have seen earlier analysis that with time the freuency of fue incresed so power aoutput also increase as the demand increases so this are not actual autliers.

# %% [markdown]
# ## Checking skew

# %%
df5.skew()
# Out:
# capacity_mw            2.286506
# latitude              -0.126900
# longitude              0.913044
# primary_fuel           0.124762
# commissioning_year    -1.014781
# genration_gwh_total    3.782487
# dtype: float64

# %% [markdown]
# As our label is skewed and gebration_gwh_total

# %% [markdown]
# ## Correlation

# %%
cor=df5.corr()
cor
# Out:
#                      capacity_mw  latitude  longitude  primary_fuel  \
# capacity_mw             1.000000  0.034655   0.004478     -0.528573
# latitude                0.034655  1.000000   0.150897     -0.018760
# longitude               0.004478  0.150897   1.000000     -0.173398
# primary_fuel           -0.528573 -0.018760  -0.173398      1.000000
# commissioning_year      0.325567  0.124145   0.133610     -0.436798
# genration_gwh_total     0.880102  0.045598   0.040029     -0.441427
#
#                      commissioning_year  genration_gwh_total
# capacity_mw                    0.325567             0.880102
# latitude                       0.124145             0.045598
# longitude                      0.133610             0.040029
# primary_fuel                  -0.436798            -0.441427
# commissioning_year             1.000000             0.189022
# genration_gwh_total            0.189022             1.000000

# %%
import numpy as np
# Visualizing the correlation matrix by plotting heatmap
mask = np.triu(np.ones_like(df5.corr(), dtype=bool))
fig, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(df5.corr(), mask=mask, cmap='inferno_r', annot=True, fmt=".1g", linewidths=0.1, ax=ax,linecolor="black")
plt.yticks(rotation=0);
plt.show()

# %% [markdown]
#  From the graph as we can see that logitude and latitude is very less correlated with label

# %% [markdown]
# # Capacity_MG Regression model

# %% [markdown]
# Splitting the label and feature

# %%
x=df5.drop('capacity_mw',axis=1)
y=df5.capacity_mw

# %% [markdown]
# ## Treating skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x=pd.DataFrame(x,columns=['latitude', 'longitude', 'primary_fuel', 'commissioning_year',
       'genration_gwh_total'])

# %%
x.skew()
# Out:
# latitude              -0.104105
# longitude              0.024219
# primary_fuel          -0.132118
# commissioning_year    -0.287549
# genration_gwh_total   -0.184704
# dtype: float64

# %% [markdown]
# Skewness is removed

# %% [markdown]
# ## VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns


vif
# Out:
#    VIF values             Features
# 0    1.047670             latitude
# 1    1.053814            longitude
# 2    1.822744         primary_fuel
# 3    1.305861   commissioning_year
# 4    1.507651  genration_gwh_total

# %% [markdown]
# Score is in acceptable range

# %% [markdown]
# ## Feature selection

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
best_features = SelectKBest(score_func=f_classif,k=5) # run multiple time and find the best

fit=best_features.fit(x,y)

df_scores=pd.DataFrame(fit.scores_)

df_columns=pd.DataFrame(x.columns)

# concatenate dataframe
feature_scores=pd.concat([df_columns,df_scores],axis=1)

feature_scores.columns=['Feature_Name','Score'] # name output columns
print(feature_scores.nlargest(5,'Score')) # print 25 best features
# Out:
#           Feature_Name      Score
# 4  genration_gwh_total  11.911406
# 2         primary_fuel   3.252271
# 3   commissioning_year   1.996494
# 1            longitude   1.327793
# 0             latitude   1.062054

# %% [markdown]
# As we have only 5 feature we are going to use all the features

# %% [markdown]
# # Model building

# %%
# importing necessary libraries

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Random State

# %%
random_states = range(1, 200)
r2_scores = []

for rs in random_states:
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=rs)
    LR = LinearRegression()
    LR.fit(x_train, y_train)
    pred = LR.predict(x_test)
    r2 = r2_score(y_test, pred)
    r2_scores.append(r2)

max_r2 = max(r2_scores)
max_rs = random_states[r2_scores.index(max_r2)]

print("Best accuracy is", max_r2, "at random_state", max_rs)
# Out:
# Best accuracy is 0.6553446268781624 at random_state 11

# %% [markdown]
# ## Trian test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=max_rs)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor

# %%
training_r2_score = []
testing_r2_score = []

# %%
def model_prediction(model):
    model.fit(x_train,y_train)
    y_pred = model.predict(x_train)
    pred = model.predict(x_test)
    a = r2_score(y_train,y_pred)*100
    b = r2_score(y_test,pred)*100
    training_r2_score.append(a)
    testing_r2_score.append(b)
    print(f"R2_Score of {model} model on Training Data is:",a)
    print(f"R2_Score of {model} model on Testing Data is:",b)
    print("\n------------------------------------------------------------------------")
    print(f"Mean Absolute Error of {model} model is:",mean_absolute_error(y_test,pred))
    print(f"Mean Square Error of {model} model is:", mean_squared_error(y_test,pred))
    print(f"Squarroot Mean Square Error  {model} model is:",np.sqrt(mean_squared_error(y_test,pred)))
    print("\n------------------------------------------------------------------------")

# %%
model_prediction(LinearRegression())
# Out:
# R2_Score of LinearRegression() model on Training Data is: 55.98078442996085
# R2_Score of LinearRegression() model on Testing Data is: 65.53446268781624
#
# ------------------------------------------------------------------------
# Mean Absolute Error of LinearRegression() model is: 291.8192305758645
# Mean Square Error of LinearRegression() model is: 149806.75764279874
# Squarroot Mean Square Error  LinearRegression() model is: 387.04877941003605
#
# ------------------------------------------------------------------------

# %%
lasscv=LassoCV(alphas=None,max_iter=10)
lasscv.fit(x_train,y_train)
# Out:
# LassoCV(max_iter=10)

# %%
alpha=lasscv.alpha_
alpha
# Out:
# 0.5224187698019997

# %%
model_prediction(Lasso(alpha))
# Out:
# R2_Score of Lasso(alpha=0.5224187698019997) model on Training Data is: 55.980563525549684
# R2_Score of Lasso(alpha=0.5224187698019997) model on Testing Data is: 65.56342459786045
#
# ------------------------------------------------------------------------
# Mean Absolute Error of Lasso(alpha=0.5224187698019997) model is: 291.69842705694583
# Mean Square Error of Lasso(alpha=0.5224187698019997) model is: 149680.87276830612
# Squarroot Mean Square Error  Lasso(alpha=0.5224187698019997) model is: 386.8861237732701
#
# ------------------------------------------------------------------------

# %%
ridgecv=RidgeCV(alphas=np.arange(0.001,0.1,0.01))
ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]))

# %%
model_prediction(Ridge(alpha=ridgecv.alpha_))
# Out:
# R2_Score of Ridge(alpha=0.09099999999999998) model on Training Data is: 55.980780707126996
# R2_Score of Ridge(alpha=0.09099999999999998) model on Testing Data is: 65.53714167752567
#
# ------------------------------------------------------------------------
# Mean Absolute Error of Ridge(alpha=0.09099999999999998) model is: 291.7838077696437
# Mean Square Error of Ridge(alpha=0.09099999999999998) model is: 149795.1132352709
# Squarroot Mean Square Error  Ridge(alpha=0.09099999999999998) model is: 387.0337365595807
#
# ------------------------------------------------------------------------

# %%
model_prediction(SVR())
# Out:
# R2_Score of SVR() model on Training Data is: -9.388592850638311
# R2_Score of SVR() model on Testing Data is: -11.225978578637852
#
# ------------------------------------------------------------------------
# Mean Absolute Error of SVR() model is: 452.6551212588711
# Mean Square Error of SVR() model is: 483451.1374532633
# Squarroot Mean Square Error  SVR() model is: 695.306506120332
#
# ------------------------------------------------------------------------

# %%
model_prediction(RandomForestRegressor())
# Out:
# R2_Score of RandomForestRegressor() model on Training Data is: 97.55668011140466
# R2_Score of RandomForestRegressor() model on Testing Data is: 84.67870479798216
#
# ------------------------------------------------------------------------
# Mean Absolute Error of RandomForestRegressor() model is: 161.31000108108108
# Mean Square Error of RandomForestRegressor() model is: 66595.03191006639
# Squarroot Mean Square Error  RandomForestRegressor() model is: 258.0601323530359
#
# ------------------------------------------------------------------------

# %%
model_prediction(GradientBoostingRegressor())
# Out:
# R2_Score of GradientBoostingRegressor() model on Training Data is: 96.7252326865205
# R2_Score of GradientBoostingRegressor() model on Testing Data is: 83.83102561097901
#
# ------------------------------------------------------------------------
# Mean Absolute Error of GradientBoostingRegressor() model is: 162.94093987350692
# Mean Square Error of GradientBoostingRegressor() model is: 70279.52605782874
# Squarroot Mean Square Error  GradientBoostingRegressor() model is: 265.1028593920268
#
# ------------------------------------------------------------------------

# %%
model_prediction(DecisionTreeRegressor())
# Out:
# R2_Score of DecisionTreeRegressor() model on Training Data is: 100.0
# R2_Score of DecisionTreeRegressor() model on Testing Data is: 69.62976005724462
#
# ------------------------------------------------------------------------
# Mean Absolute Error of DecisionTreeRegressor() model is: 229.28120945945946
# Mean Square Error of DecisionTreeRegressor() model is: 132006.2743675743
# Squarroot Mean Square Error  DecisionTreeRegressor() model is: 363.3266772032771
#
# ------------------------------------------------------------------------

# %%
model_prediction(KNeighborsRegressor())
# Out:
# R2_Score of KNeighborsRegressor() model on Training Data is: 79.77373606102405
# R2_Score of KNeighborsRegressor() model on Testing Data is: 78.06038257700246
#
# ------------------------------------------------------------------------
# Mean Absolute Error of KNeighborsRegressor() model is: 191.3347216216216
# Mean Square Error of KNeighborsRegressor() model is: 95362.01105156864
# Squarroot Mean Square Error  KNeighborsRegressor() model is: 308.8074012253732
#
# ------------------------------------------------------------------------

# %%
model_prediction(AdaBoostRegressor())
# Out:
# R2_Score of AdaBoostRegressor() model on Training Data is: 85.68705317843246
# R2_Score of AdaBoostRegressor() model on Testing Data is: 73.36683628918759
#
# ------------------------------------------------------------------------
# Mean Absolute Error of AdaBoostRegressor() model is: 258.01991520912026
# Mean Square Error of AdaBoostRegressor() model is: 115762.82316876086
# Squarroot Mean Square Error  AdaBoostRegressor() model is: 340.2393615805803
#
# ------------------------------------------------------------------------

# %%
model_prediction(XGBRegressor())
# Out:
# R2_Score of XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...) model on Training Data is: 99.99830108705909
# R2_Score of XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
# ...

# %%
models=['LinearRegression','Lasso','Ridge','SVR','RandomForestRegressor','GradientBoostingRegressor','DecisionTreeRegressor','KNeighborsRegressor','AdaBoostRegressor','XGBRegressor']

# %% [markdown]
# ## Model perfrormance analysis

# %%
df6 = pd.DataFrame({"Algorithms":models,
                   "Training R2 Score":training_r2_score,
                   "Testing R2 Score":testing_r2_score
                  })
df6
# Out:
#                   Algorithms  Training R2 Score  Testing R2 Score
# 0           LinearRegression          55.980784         65.534463
# 1                      Lasso          55.980564         65.563425
# 2                      Ridge          55.980781         65.537142
# 3                        SVR          -9.388593        -11.225979
# 4      RandomForestRegressor          97.556680         84.678705
# 5  GradientBoostingRegressor          96.725233         83.831026
# 6      DecisionTreeRegressor         100.000000         69.629760
# 7        KNeighborsRegressor          79.773736         78.060383
# 8          AdaBoostRegressor          85.687053         73.366836
# 9               XGBRegressor          99.998301         81.518648

# %%
df6.plot(x="Algorithms",y=["Training R2 Score","Testing R2 Score"], figsize=(16,6),kind="bar",
        title="Performance Visualization of Different Models",colormap="Set1")
plt.yticks(range(60,106,5))
plt.show()

# %% [markdown]
# RandomForestRegressor is best model but we are going to cross validate further.

# %% [markdown]
# ## Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
num_folds_range = range(2,20)

model = LinearRegression()

fold_performance = {}

for num_folds in num_folds_range:
    scores = cross_val_score(model, x, y, cv=num_folds, scoring='neg_mean_squared_error')  # or 'r2' for coefficient of determination
    fold_performance[num_folds] = {
        'mean': np.mean(scores),
        'std': np.std(scores)
    }
    
df_fold_performance = pd.DataFrame(fold_performance).transpose()

print(df_fold_performance)
# Out:
#              mean            std
# 2  -230662.126730   63723.423137
# 3  -227826.958193   57750.715268
# 4  -220464.505097   72706.909696
# 5  -219313.154500   73843.852300
# 6  -220145.618069   73622.480126
# 7  -221963.859504   89414.890185
# 8  -219705.847235   92125.110308
# 9  -221252.718467   88612.164621
# 10 -218379.856682   99501.756974
# 11 -220539.402272   90266.978532
# 12 -217908.051448  112934.183783
# 13 -219501.198383  106073.025057
# 14 -219682.157695  129931.553821
# 15 -219041.836562  106651.982877
# 16 -220366.299545  140294.202817
# 17 -217336.298044  110323.621490
# 18 -220142.710976  150026.880622
# 19 -218336.268817  151793.362925

# %% [markdown]
# After analysisng the cv 5 is best as it tradeoff between Meana and Std.

# %%
# checking cv score for logistic Regression
score = cross_val_score(LinearRegression(),x,y,cv=5)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[0]/100)- score.mean())
# Out:
# [0.55283521 0.5403296  0.54053059 0.66223902 0.52105018]
# 0.5633969173241554
# Differnet between Accuracy score and cross validation score is-  0.091947709554007

# %%
# checking cv score for logistic Regression
score = cross_val_score(Lasso(),x,y,cv=5)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[1]/100)- score.mean())
# Out:
# [0.55310403 0.54155925 0.53917328 0.66222354 0.52137599]
# 0.563487219082839
# Differnet between Accuracy score and cross validation score is-  0.09214702689576537

# %%
# checking cv score for logistic Regression
score = cross_val_score(Ridge(),x,y,cv=5)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[2]/100)- score.mean())
# Out:
# [0.5530619  0.54157627 0.54032952 0.66199113 0.52092231]
# 0.5635762257657058
# Differnet between Accuracy score and cross validation score is-  0.09179519100955091

# %%
# checking cv score for logistic Regression
score = cross_val_score(SVR(),x,y,cv=5)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[3]/100)- score.mean())
# Out:
# [-0.01901877 -0.07447941 -0.12527105 -0.11424105 -0.10955235]
# -0.08851252493527513
# Differnet between Accuracy score and cross validation score is-  -0.02374726085110339

# %%
# checking cv score for logistic Regression
score = cross_val_score(RandomForestRegressor(),x,y,cv=5)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[4]/100)- score.mean())
# Out:
# [0.84169509 0.80749714 0.86163159 0.84631098 0.83763793]
# 0.8389545449235637
# Differnet between Accuracy score and cross validation score is-  0.007832503056257933

# %%
# checking cv score for logistic Regression
score = cross_val_score(GradientBoostingRegressor(),x,y, cv=5)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[5]/100)- score.mean())
# Out:
# [0.85229353 0.80383018 0.87968735 0.81733269 0.82507773]
# 0.8356442949394791
# Differnet between Accuracy score and cross validation score is-  0.0026659611703110375

# %%
# checking cv score for logistic Regression
score = cross_val_score(DecisionTreeRegressor(),x,y, cv=5)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[6]/100)- score.mean())
# Out:
# [0.54105074 0.64289922 0.80542754 0.74508466 0.67827746]
# 0.682547923220254
# Differnet between Accuracy score and cross validation score is-  0.013749677352192236

# %%
# checking cv score for logistic Regression
score = cross_val_score(KNeighborsRegressor(),x,y,cv=5)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[7]/100)- score.mean())
# Out:
# [0.68564023 0.67991193 0.41805002 0.79872639 0.74077996]
# 0.6646217052547359
# Differnet between Accuracy score and cross validation score is-  0.11598212051528867

# %%
# checking cv score for logistic Regression
score = cross_val_score(AdaBoostRegressor(),x,y,cv=5)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[8]/100)- score.mean())
# Out:
# [0.6835594  0.70759293 0.81298133 0.82171063 0.74864877]
# 0.7548986119659766
# Differnet between Accuracy score and cross validation score is-  -0.02123024907410076

# %%
# checking cv score for logistic Regression
score = cross_val_score(XGBRegressor(),x,y,cv=5)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[9]/100)- score.mean())
# Out:
# [0.83729441 0.78334712 0.86647913 0.8462992  0.83132055]
# 0.8329480821174535
# Differnet between Accuracy score and cross validation score is-  -0.01776160612439237

# %% [markdown]
# XGBRegressor,GradientBoostingRegressor and RandomForestRegressor are best models with  highest r2 score and least difference in cross validation

# %% [markdown]
# ## Gridsearch cv

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### RandomForestRegressor

# %%
model1 = RandomForestRegressor()
parameters1 ={'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
             'min_samples_split':[2,3,5],
             'max_features':['sqrt', 'log2', None],
             'random_state':[75,100,150]
             }

grid_search1 = GridSearchCV(model1, parameters1, cv=4, n_jobs=-1)
grid_search1.fit(x_train,y_train)
grid_search1.best_score_
# Out:
# 0.8157273106263112

# %%
grid_search1.best_estimator_
best=grid_search1.best_params_
best
# Out:
# {'criterion': 'poisson',
#  'max_features': None,
#  'min_samples_split': 3,
#  'random_state': 100}

# %%
model1=RandomForestRegressor(criterion = 'poisson',max_features= None,min_samples_split= 3,random_state= 100)

# %%
model1.fit(x_train,y_train)

x_test_pred1 = model1.predict(x_test)

r2_score(y_test,x_test_pred1)
# Out:
# 0.8502883468294429

# %% [markdown]
# ### XGBRegressor

# %%
model2=XGBRegressor()

# %%
parameters2 ={'booster':['gbtree', 'gblinear', 'dart'],
             'learning_rate':[0.005,.01,.02],
             'disable_default_eval_metric':[True,False]
             }

# %%
grid_search = GridSearchCV(model2, param_grid=parameters2, cv=3)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
# ...

# %%
grid_search.best_estimator_
best=grid_search.best_params_
best
# Out:
# {'booster': 'gbtree',
#  'disable_default_eval_metric': True,
#  'learning_rate': 0.02}

# %%
model2=XGBRegressor(booster= 'dart', disable_default_eval_metric= True, learning_rate= 0.02)

# %%
model2.fit(x_train,y_train)

x_test_pred2 = model2.predict(x_test)

r2_score(y_test,x_test_pred2)
# Out:
# 0.7685257062003126

# %% [markdown]
# ### GradientBoostingRegressor

# %%
model3=GradientBoostingRegressor()

# %%
param_grid={'loss':['squared_error', 'absolute_error', 'huber', 'quantile'],
           'criterion':['friedman_mse', 'squared_error'],
           'learning_rate':[.005,.01,.02,.04],
           'n_estimators':[50,100,150]}

# %%
grid_search = GridSearchCV(model3, param_grid=param_grid, cv=3)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error'],
#                          'learning_rate': [0.005, 0.01, 0.02, 0.04],
#                          'loss': ['squared_error', 'absolute_error', 'huber',
#                                   'quantile'],
#                          'n_estimators': [50, 100, 150]})

# %%
grid_search.best_estimator_
best=grid_search.best_params_
best
# Out:
# {'criterion': 'squared_error',
#  'learning_rate': 0.04,
#  'loss': 'huber',
#  'n_estimators': 150}

# %%
model3=GradientBoostingRegressor(criterion= 'squared_error', learning_rate= 0.02 , loss= 'squared_error', n_estimators= 150)

# %%
model3.fit(x_train,y_train)

x_test_pred3 = model3.predict(x_test)

r2_score(y_test,x_test_pred3)
# Out:
# 0.8300931218756153

# %% [markdown]
# ## Saving the model

# %%
import pickle
filename='Capacity.pkl'
pickle.dump(model1,open(filename,'wb'))#saved model

# %% [markdown]
# ## Loading model

# %%
loaded_model=pickle.load(open('Capacity.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 85.0288346829443

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=['Predicted','Original'])
conclusion
# Out:
#                  0        1           2          3           4         5    \
# Predicted  13.263467  1163.58  131.560333  12.362151  491.720869  47.36195
# Original    4.000000  1050.00  234.000000   4.500000   25.000000  26.00000
#
#                   6          7           8           9         10      11   \
# Predicted  136.326967  44.578679  397.068133  136.981924  82.73385  42.719
# Original   150.000000  36.000000  396.000000  240.000000  60.00000  36.000
#
#                   12           13           14           15           16   \
# Predicted  271.646593   677.507294  1583.856667  3388.325714   627.536967
# Original   211.955000  1320.000000  1340.000000  2980.000000  1200.000000
#
#                   17          18          19          20         21   \
# Predicted  313.757883  385.487278  674.215833  220.945345  13.312134
# Original   520.000000  702.860000  500.000000  815.600000   9.000000
#
# ...

# %% [markdown]
# # Classification model.

# %%
df5.head()
# Out:
#    capacity_mw  latitude  longitude  primary_fuel  commissioning_year  \
# 3        135.0   23.8712    91.3602             1              2004.0
# 4       1800.0   21.9603    82.4091             0              2015.0
# 5        250.0   23.7689    68.6447             0              2005.0
# 6         60.0   10.4547    77.0078             2              1970.0
# 7        192.0   32.2258    77.2070             2              2010.0
#
#    genration_gwh_total
# 3          3637.554320
# 4         27859.499736
# 5          5662.606000
# 6           509.131550
# 7          3330.364500

# %%
# Checking the unique values 
df5.primary_fuel.unique()
# Out:
# array([1, 0, 2, 4, 3])

# %%
# chaning the multiclass classification into binary
df5[((df5['primary_fuel']==2) | (df5['primary_fuel']==3) | (df5['primary_fuel'] == 4))]=1

# %%
df5.primary_fuel.unique()
# Out:
# array([1, 0])

# %%
# Checking the value count
df5.primary_fuel.value_counts()
# Out:
# 1    308
# 0    184
# Name: primary_fuel, dtype: int64

# %% [markdown]
# ## Checking skewness

# %%
df5.skew()
# Out:
# capacity_mw            2.366591
# latitude               0.317033
# longitude              0.058251
# primary_fuel          -0.522474
# commissioning_year     0.032789
# genration_gwh_total    3.855125
# dtype: float64

# %% [markdown]
# Capacity_mw and genration_gwh_total are highly skewed

# %% [markdown]
# ## Correaltion

# %%
cor=df5.corr()
cor
# Out:
#                      capacity_mw  latitude  longitude  primary_fuel  \
# capacity_mw             1.000000  0.616090   0.621536     -0.662807
# latitude                0.616090  1.000000   0.942316     -0.766256
# longitude               0.621536  0.942316   1.000000     -0.787795
# primary_fuel           -0.662807 -0.766256  -0.787795      1.000000
# commissioning_year      0.630672  0.942970   0.995747     -0.786162
# genration_gwh_total     0.893544  0.468029   0.472960     -0.555481
#
#                      commissioning_year  genration_gwh_total
# capacity_mw                    0.630672             0.893544
# latitude                       0.942970             0.468029
# longitude                      0.995747             0.472960
# primary_fuel                  -0.786162            -0.555481
# commissioning_year             1.000000             0.474481
# genration_gwh_total            0.474481             1.000000

# %%
# Visualizing the correlation matrix by plotting heatmap
mask = np.triu(np.ones_like(df5.corr(), dtype=bool))
fig, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(df5.corr(), mask=mask, cmap='inferno_r', annot=True, fmt=".1g", linewidths=0.1, ax=ax,linecolor="black")
plt.yticks(rotation=0);
plt.show()

# %% [markdown]
# From the above graph we can see that the values are highly correlated.

# %% [markdown]
# Splitting feature and label

# %%
x=df5.drop('primary_fuel',axis=1)
y=df5.primary_fuel

# %%
x.columns
# Out:
# Index(['capacity_mw', 'latitude', 'longitude', 'commissioning_year',
#        'genration_gwh_total'],
#       dtype='object')

# %% [markdown]
# ## Skewness correction

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x= pd.DataFrame(x,columns=['capacity_mw', 'latitude', 'longitude', 'commissioning_year',
       'genration_gwh_total'])

# %%
x.skew()
# Out:
# capacity_mw            0.144901
# latitude               0.084546
# longitude              0.034216
# commissioning_year     0.032627
# genration_gwh_total    0.217191
# dtype: float64

# %%
# Reset the index
x = x.reset_index(drop=True)

y = y.reset_index(drop=True)

# %%
# Concatinating the data frame
df8 = pd.concat([x, y], axis=1)
df8.shape
# Out:
# (492, 6)

# %%
df8.skew()
# Out:
# capacity_mw            0.144901
# latitude               0.084546
# longitude              0.034216
# commissioning_year     0.032627
# genration_gwh_total    0.217191
# primary_fuel          -0.522474
# dtype: float64

# %%
x=df8.drop('primary_fuel',axis=1)
y=df8.primary_fuel

# %%
plt.figure(figsize=(18,18),facecolor="white")
plotnumber=1
for col in x:
    if plotnumber<=5:
        ax=plt.subplot(3,2,plotnumber)
        sns.distplot(x[col])
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ## Removing collinearity

# %%
# Finding VIF in each scaled column i.e x.shape[1]/(1/(1-r2))
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns


vif
# Out:
#     VIF values             Features
# 0    35.869656          capacity_mw
# 1    54.264229             latitude
# 2  1992.553717            longitude
# 3  2044.495934   commissioning_year
# 4    10.769544  genration_gwh_total

# %% [markdown]
# VIF score is high Commissioning year

# %%
x.drop('commissioning_year',inplace= True , axis=1 )

# %%
# Finding VIF in each scaled column i.e x.shape[1]/(1/(1-r2))
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns


vif
# Out:
#    VIF values             Features
# 0   33.291519          capacity_mw
# 1   54.246910             latitude
# 2   66.619298            longitude
# 3   10.601007  genration_gwh_total

# %% [markdown]
# ## Selecting the best feature

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
best_features = SelectKBest(score_func=f_classif,k=4) # run multiple time and find the best

fit=best_features.fit(x,y)

df_scores=pd.DataFrame(fit.scores_)

df_columns=pd.DataFrame(x.columns)

# concatenate dataframe
feature_scores=pd.concat([df_columns,df_scores],axis=1)

feature_scores.columns=['Feature_Name','Score'] # name output columns
print(feature_scores.nlargest(4,'Score')) # print 4 best features
# Out:
#           Feature_Name        Score
# 0          capacity_mw  1015.607231
# 3  genration_gwh_total   919.600988
# 1             latitude   814.248628
# 2            longitude   797.105091

# %% [markdown]
# ## Treating the Imbalance dataset

# %%
y.value_counts()
# Out:
# 1    308
# 0    184
# Name: primary_fuel, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
SM= SMOTE()
x,y=SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 1    308
# 0    308
# Name: primary_fuel, dtype: int64

# %%
x.shape
# Out:
# (616, 4)

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    LR=LogisticRegression()
    LR.fit(x_train,y_train)
    pred=LR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
    
print("Best accuracy is",maxAccu,"at random_state",maxRS)
# Out:
# Best accuracy is 0.9513513513513514 at random_state 83

# %% [markdown]
# ## Train test split

# %%
 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=maxRS)

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix

# %%
training_score = []
testing_score = []

# %%
def model_prediction(model):
    model.fit(x_train,y_train)
    x_train_pred = model.predict(x_train)
    x_test_pred = model.predict(x_test)
    a = accuracy_score(y_train,x_train_pred)*100
    b = accuracy_score(y_test,x_test_pred)*100
    training_score.append(a)
    testing_score.append(b)
    
    print(f"Accuracy_Score of {model} model on Training Data is:",a)
    print(f"Accuracy_Score of {model} model on Testing Data is:",b)
    print("\n------------------------------------------------------------------------")
    print(f"Precision Score of {model} model is:",precision_score(y_test,x_test_pred))
    print(f"Recall Score of {model} model is:",recall_score(y_test,x_test_pred))
    print(f"F1 Score of {model} model is:",f1_score(y_test,x_test_pred))
    print("\n------------------------------------------------------------------------")
    print(f"Confusion Matrix of {model} model is:")
    cm = confusion_matrix(y_test,x_test_pred)
    plt.figure(figsize=(8,4))
    sns.heatmap(cm,annot=True,fmt="g",cmap="summer")
    plt.show()

# %%
model_prediction(LogisticRegression())
# Out:
# Accuracy_Score of LogisticRegression() model on Training Data is: 88.63109048723898
# Accuracy_Score of LogisticRegression() model on Testing Data is: 95.13513513513514
#
# ------------------------------------------------------------------------
# Precision Score of LogisticRegression() model is: 0.9868421052631579
# Recall Score of LogisticRegression() model is: 0.9036144578313253
# F1 Score of LogisticRegression() model is: 0.9433962264150944
#
# ------------------------------------------------------------------------
# Confusion Matrix of LogisticRegression() model is:

# %%
model_prediction(SVC())
# Out:
# Accuracy_Score of SVC() model on Training Data is: 89.0951276102088
# Accuracy_Score of SVC() model on Testing Data is: 94.05405405405406
#
# ------------------------------------------------------------------------
# Precision Score of SVC() model is: 1.0
# Recall Score of SVC() model is: 0.8674698795180723
# F1 Score of SVC() model is: 0.9290322580645161
#
# ------------------------------------------------------------------------
# Confusion Matrix of SVC() model is:

# %%
model_prediction(DecisionTreeClassifier())
# Out:
# Accuracy_Score of DecisionTreeClassifier() model on Training Data is: 100.0
# Accuracy_Score of DecisionTreeClassifier() model on Testing Data is: 96.75675675675676
#
# ------------------------------------------------------------------------
# Precision Score of DecisionTreeClassifier() model is: 0.9529411764705882
# Recall Score of DecisionTreeClassifier() model is: 0.9759036144578314
# F1 Score of DecisionTreeClassifier() model is: 0.9642857142857143
#
# ------------------------------------------------------------------------
# Confusion Matrix of DecisionTreeClassifier() model is:

# %%
model_prediction(RandomForestClassifier())
# Out:
# Accuracy_Score of RandomForestClassifier() model on Training Data is: 100.0
# Accuracy_Score of RandomForestClassifier() model on Testing Data is: 95.13513513513514
#
# ------------------------------------------------------------------------
# Precision Score of RandomForestClassifier() model is: 0.9512195121951219
# Recall Score of RandomForestClassifier() model is: 0.9397590361445783
# F1 Score of RandomForestClassifier() model is: 0.9454545454545454
#
# ------------------------------------------------------------------------
# Confusion Matrix of RandomForestClassifier() model is:

# %%
model_prediction(ExtraTreesClassifier())
# Out:
# Accuracy_Score of ExtraTreesClassifier() model on Training Data is: 100.0
# Accuracy_Score of ExtraTreesClassifier() model on Testing Data is: 97.2972972972973
#
# ------------------------------------------------------------------------
# Precision Score of ExtraTreesClassifier() model is: 0.975609756097561
# Recall Score of ExtraTreesClassifier() model is: 0.963855421686747
# F1 Score of ExtraTreesClassifier() model is: 0.9696969696969697
#
# ------------------------------------------------------------------------
# Confusion Matrix of ExtraTreesClassifier() model is:

# %%
model_prediction(AdaBoostClassifier())
# Out:
# Accuracy_Score of AdaBoostClassifier() model on Training Data is: 99.30394431554525
# Accuracy_Score of AdaBoostClassifier() model on Testing Data is: 96.75675675675676
#
# ------------------------------------------------------------------------
# Precision Score of AdaBoostClassifier() model is: 0.963855421686747
# Recall Score of AdaBoostClassifier() model is: 0.963855421686747
# F1 Score of AdaBoostClassifier() model is: 0.963855421686747
#
# ------------------------------------------------------------------------
# Confusion Matrix of AdaBoostClassifier() model is:

# %%
model_prediction(GradientBoostingClassifier())
# Out:
# Accuracy_Score of GradientBoostingClassifier() model on Training Data is: 100.0
# Accuracy_Score of GradientBoostingClassifier() model on Testing Data is: 96.21621621621622
#
# ------------------------------------------------------------------------
# Precision Score of GradientBoostingClassifier() model is: 0.9634146341463414
# Recall Score of GradientBoostingClassifier() model is: 0.9518072289156626
# F1 Score of GradientBoostingClassifier() model is: 0.9575757575757576
#
# ------------------------------------------------------------------------
# Confusion Matrix of GradientBoostingClassifier() model is:

# %%
model_prediction(XGBClassifier())
# Out:
# Accuracy_Score of XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...) model on Training Data is: 100.0
# Accuracy_Score of XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
# ...

# %%
models = ["Logistic Regression","SVM","Decision Tree","Random Forest","Extra Tree","Ada Boost",
          "Gradient Boost","XGBoost"]

# %%
df9 = pd.DataFrame({"Algorithms":models,
                   "Training Score":training_score,
                   "Testing Score":testing_score})

# %%
df9
# Out:
#             Algorithms  Training Score  Testing Score
# 0  Logistic Regression       88.631090      95.135135
# 1                  SVM       89.095128      94.054054
# 2        Decision Tree      100.000000      96.756757
# 3        Random Forest      100.000000      95.135135
# 4           Extra Tree      100.000000      97.297297
# 5            Ada Boost       99.303944      96.756757
# 6       Gradient Boost      100.000000      96.216216
# 7              XGBoost      100.000000      95.675676

# %%
df9.plot(x="Algorithms",y=["Training Score","Testing Score"], figsize=(16,6),kind="bar",
        title="Performance Visualization of Different Models",colormap="Set1")
plt.show()

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
num_folds_range = range(2, 20)

model = LogisticRegression()

fold_performance = {}

for num_folds in num_folds_range:
    scores = cross_val_score(model, x, y, cv=num_folds, scoring='accuracy')  # or other classification scoring metrics
    fold_performance[num_folds] = {
        'mean': np.mean(scores),
        'std': np.std(scores)
    }

df_fold_performance = pd.DataFrame(fold_performance).transpose()

print(df_fold_performance)
# Out:
#         mean       std
# 2   0.912338  0.012987
# 3   0.910735  0.011992
# 4   0.909091  0.016555
# 5   0.909061  0.025997
# 6   0.909147  0.030969
# 7   0.912338  0.040160
# 8   0.905844  0.040422
# 9   0.907573  0.038117
# 10  0.909201  0.047971
# 11  0.907468  0.040160
# 12  0.907554  0.042676
# 13  0.907597  0.044569
# 14  0.907468  0.050429
# 15  0.907472  0.057845
# 16  0.907684  0.051421
# 17  0.907525  0.055753
# 18  0.905929  0.052631
# 19  0.907695  0.051406

# %% [markdown]
# Cv value 4 is best tradeoff

# %%
# checking cv score for logistic Regression
score = cross_val_score(LogisticRegression(),x,y,cv=4)
print(score)
print(score.mean())
print(testing_score[0]/100)
print("Differnet between Accuracy score and cross validation score is- ", (testing_score[0]/100)- score.mean())
# Out:
# [0.8961039  0.88961039 0.92207792 0.92857143]
# 0.9090909090909092
# 0.9513513513513514
# Differnet between Accuracy score and cross validation score is-  0.04226044226044223

# %%
# checking cv score for SVC
score = cross_val_score(SVC(),x,y,cv=4)
print(score)
print(score.mean())
print(testing_score[1]/100)
print("Differnet between Accuracy score and cross validation score is- ", (testing_score[1]/100)- score.mean())
# Out:
# [0.88961039 0.8961039  0.90909091 0.92857143]
# 0.9058441558441559
# 0.9405405405405406
# Differnet between Accuracy score and cross validation score is-  0.0346963846963847

# %%
# checking cv score for DecisionTreeClassifier
score = cross_val_score(DecisionTreeClassifier(),x,y,cv=4)
print(score)
print(score.mean())
print(testing_score[2]/100)
print("Differnet between Accuracy score and cross validation score is- ", (testing_score[2]/100)- score.mean())
# Out:
# [0.91558442 0.94155844 0.94155844 0.97402597]
# 0.9431818181818181
# 0.9675675675675676
# Differnet between Accuracy score and cross validation score is-  0.024385749385749445

# %%
# checking cv score for RandomForestClassifier
score = cross_val_score(RandomForestClassifier(),x,y,cv=4)
print(score)
print(score.mean())
print(testing_score[3]/100)
print("Differnet between Accuracy score and cross validation score is- ", (testing_score[3]/100)- score.mean())
# Out:
# [0.94155844 0.96753247 0.92857143 0.98051948]
# 0.9545454545454546
# 0.9513513513513514
# Differnet between Accuracy score and cross validation score is-  -0.0031941031941031817

# %%
# checking cv score for ExtraTreesClassifier
score = cross_val_score(ExtraTreesClassifier(),x,y,cv=4)
print(score)
print(score.mean())
print(testing_score[4]/100)
print("Differnet between Accuracy score and cross validation score is- ", (testing_score[4]/100)- score.mean())
# Out:
# [0.94155844 0.96103896 0.94805195 0.97402597]
# 0.9561688311688312
# 0.972972972972973
# Differnet between Accuracy score and cross validation score is-  0.016804141804141803

# %%
# checking cv score for AdaBoostClassifier
score = cross_val_score(AdaBoostClassifier(),x,y,cv=4)
print(score)
print(score.mean())
print(testing_score[5]/100)
print("Differnet between Accuracy score and cross validation score is- ", (testing_score[5]/100)- score.mean())
# Out:
# [0.92207792 0.95454545 0.93506494 0.97402597]
# 0.9464285714285714
# 0.9675675675675676
# Differnet between Accuracy score and cross validation score is-  0.02113899613899617

# %%
# checking cv score for GradientBoostingClassifier
score = cross_val_score(GradientBoostingClassifier(),x,y,cv=4)
print(score)
print(score.mean())
print(testing_score[6]/100)
print("Differnet between Accuracy score and cross validation score is- ", (testing_score[6]/100)- score.mean())
# Out:
# [0.92857143 0.97402597 0.93506494 0.95454545]
# 0.948051948051948
# 0.9621621621621622
# Differnet between Accuracy score and cross validation score is-  0.014110214110214181

# %%
# checking cv score for XGBClassifier
score = cross_val_score(XGBClassifier(),x,y,cv=4)
print(score)
print(score.mean())
print(testing_score[7]/100)
print("Differnet between Accuracy score and cross validation score is- ", (testing_score[7]/100)- score.mean())
# Out:
# [0.92207792 0.96753247 0.93506494 0.97402597]
# 0.9496753246753247
# 0.9567567567567568
# Differnet between Accuracy score and cross validation score is-  0.007081432081432082

# %% [markdown]
# Best model are XGBClassifier,GradientBoostingClassifier and DecisionTreeClassifier

# %% [markdown]
# ## Hyperperamater tuining

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### DecisionTreeClassifier

# %%
model1 = DecisionTreeClassifier()
parameters1 ={'criterion':['gini', 'entropy','log_loss'],
             'min_samples_split':[3,5,6,7,9],
             'max_features':['auto','sqrt', 'log2'],
             'random_state':[75,100,150]
             }

grid_search1 = GridSearchCV(model1, parameters1, cv=4, n_jobs=-1)
grid_search1.fit(x_train,y_train)
grid_search1.best_score_
# Out:
# 0.9373269297334718

# %%
best_parameters1 = grid_search1.best_params_
best_parameters1
# Out:
# {'criterion': 'gini',
#  'max_features': 'auto',
#  'min_samples_split': 5,
#  'random_state': 150}

# %%
model1=DecisionTreeClassifier(criterion= 'gini', max_features= 'auto', min_samples_split= 50, random_state= 150)

# %%
model1.fit(x_train,y_train)

x_test_pred1 = model1.predict(x_test)

accuracy_score(y_test,x_test_pred1)
# Out:
# 0.9351351351351351

# %% [markdown]
# ### GradientBoostingClassifier

# %%
model2 = GradientBoostingClassifier()
parameters2 ={'criterion':['friedman_mse', 'squared_error'],
             'learning_rate':[0.005,.01,.02],
             'n_estimators':[50,100,200],
             'loss':['log_loss', 'exponential']
             }

grid_search2 = GridSearchCV(model2, parameters2, cv=4, n_jobs=-1)
grid_search2.fit(x_train,y_train)
grid_search2.best_score_
# Out:
# 0.9418916580131533

# %%
best_parameters2 = grid_search2.best_params_
best_parameters2
# Out:
# {'criterion': 'friedman_mse',
#  'learning_rate': 0.02,
#  'loss': 'log_loss',
#  'n_estimators': 200}

# %%
model2=GradientBoostingClassifier(criterion= 'friedman_mse',learning_rate= 0.02,loss= 'log_loss',n_estimators= 200)

# %%
model2.fit(x_train,y_train)

x_test_pred2 = model2.predict(x_test)

accuracy_score(y_test,x_test_pred2)
# Out:
# 0.9621621621621622

# %% [markdown]
# ### XGBClassifier

# %%
model3=XGBClassifier()

# %%
parameters3 ={'booster':['gbtree', 'gblinear', 'dart'],
             'learning_rate':[0.005,.01,.02],
             'disable_default_eval_metric':[True,False],
             'max_depth':[5,6,7]
             }

grid_search3 = GridSearchCV(model3, parameters3, cv=13, n_jobs=-1)
grid_search3.fit(x_train,y_train)
grid_search3.best_score_
# Out:
# 0.9442616207322091

# %%
best_parameters3 = grid_search3.best_params_
best_parameters3
# Out:
# {'booster': 'gbtree',
#  'disable_default_eval_metric': True,
#  'learning_rate': 0.02,
#  'max_depth': 7}

# %%
model3=XGBClassifier(booster= 'gbtree',disable_default_eval_metric= True,learning_rate= 0.02,max_depth= 7)

# %%
model3.fit(x_train,y_train)

x_test_pred3 = model3.predict(x_test)

accuracy_score(y_test,x_test_pred3)
# Out:
# 0.9459459459459459

# %% [markdown]
# ## ROC AUC

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve

# Calculate and plot ROC curve for model1
y_pred_prob1 = model1.predict_proba(x_test)[:, 1]
fpr1, tpr1, thresholds1 = roc_curve(y_test, y_pred_prob1)
roc_auc1 = auc(fpr1, tpr1)
plt.plot(fpr1, tpr1, label='Model 1 (AUC = %0.2f)' % roc_auc1)

# Calculate and plot ROC curve for model2
y_pred_prob2 = model2.predict_proba(x_test)[:, 1]
fpr2, tpr2, thresholds2 = roc_curve(y_test, y_pred_prob2)
roc_auc2 = auc(fpr2, tpr2)
plt.plot(fpr2, tpr2, label='Model 2 (AUC = %0.2f)' % roc_auc2)

# Calculate and plot ROC curve for model3
y_pred_prob3 = model3.predict_proba(x_test)[:, 1]
fpr3, tpr3, thresholds3 = roc_curve(y_test, y_pred_prob3)
roc_auc3 = auc(fpr3, tpr3)
plt.plot(fpr3, tpr3, label='Model 3 (AUC = %0.2f)' % roc_auc3)

# Plot the random guess line
plt.plot([0, 1], [0, 1], 'k--')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Calculate AUC scores
auc_score1 = roc_auc_score(y_test, model1.predict(x_test))
print('AUC Score for Model 1:', auc_score1)

auc_score2 = roc_auc_score(y_test, model2.predict(x_test))
print('AUC Score for Model 2:', auc_score2)

auc_score3 = roc_auc_score(y_test, model3.predict(x_test))
print('AUC Score for Model 3:', auc_score3)
# Out:
# AUC Score for Model 1: 0.9344436569808646
# AUC Score for Model 2: 0.9623198677061187
# AUC Score for Model 3: 0.9464918497519489

# %% [markdown]
# ## Saving the model

# %%
# Saving the model using .pkl
import joblib
joblib.dump(model2,"Primary fuel.pkl")
# Out:
# ['Primary fuel.pkl']

# %% [markdown]
# ## Loading the model

# %%
# Let's load the saved model and get the predictions
model=joblib.load("Primary fuel.pkl")

# %%
# Prediction
prediction=model.predict(x_test)

# %%
a=np.array(y_test)
df10=pd.DataFrame()
df10['Predicted']=prediction
df10['Original']=a
df10
# Out:
#      Predicted  Original
# 0            1         1
# 1            0         1
# 2            0         0
# 3            0         0
# 4            1         1
# ..         ...       ...
# 180          1         1
# 181          0         0
# 182          1         1
# 183          1         1
# 184          0         0
#
# [185 rows x 2 columns]
