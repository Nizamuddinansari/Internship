# %% [markdown]
# # Project Description
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features --
#
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6.	3B - This means a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or base runner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %% [markdown]
# -- Output: Number of predicted wins (W)
# To understand the columns meaning, follow the link given below to understand the baseball statistics:
#
# https://en.wikipedia.org/wiki/Baseball_statistics
#
# For downloading the dataset, use the link given below.
#
# Dataset Link-
#
# •	https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv

# %% [markdown]
# # Laoding dataset

# %%
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # EDA

# %% [markdown]
# ## Static Analysis

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
# Checking the shape
df.shape
# Out:
# (30, 17)

# %% [markdown]
# Dataset contain 30 rows and 17 columns in which 16 is features and 1 is label that is w

# %%
# Checking the null values
df.isna().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Dataset have no null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# It have  float64(1), int64(16) data type and consume memory usage: 4.1 KB

# %%
df.nunique().to_frame()
# Out:
#       0
# W    24
# R    28
# AB   29
# H    29
# 2B   22
# 3B   23
# HR   27
# BB   29
# SO   29
# SB   27
# RA   30
# ER   30
# ERA  30
# CG    9
# SHO  12
# SV   20
# E    21

# %% [markdown]
# Checking the number of unique values in each features

# %%
df.duplicated().value_counts()
# Out:
# False    30
# dtype: int64

# %% [markdown]
# There is no duplicate values

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# From description:-
#
# 1.All column have 30 values so no missing value present.
#
# 2.The std is normal for mean.
#
# 3.All the minimum value are value and possible
#
# 4.The difference between min,25%,50%,75% and normal.
#
# 5.The mean value is almost same as the median (50%).

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Checking outliers

# %% [markdown]
# ## Data augmentation
# - It is done to increase the number of data points so that our model can train and perform properly.

# %%
# defining a function which isinterploating the data to genrate new data points 
def interpolate_data(data, num_samples=5):
    # num_samples=5 is for creating 5 data point between 2 consicutive data points.
    augmented_data = []
    for i in range(data.shape[0] - 1):
        #iterating between 1 to 29 in between 2 data points
        for j in range(num_samples):
            #iterating for no. of new data point to be genrated in this case we use 5
            alpha = float(j + 1) / (num_samples + 1)
            #alpha is a factor used to genrate new samples
            new_sample = alpha * data[i] + (1 - alpha) * data[i + 1]
            augmented_data.append(new_sample)
    augmented_data = np.vstack(augmented_data)
    # vstack is used to vertically stacking one array after the other
    return np.vstack((data, augmented_data))

    #output will be 29*5 +30 origanl dataset total 175  

def extrapolate_data(data, num_samples=5, extrapolation_factor=1.5):
    augmented_data = []
    for i in range(data.shape[0]):
        for j in range(num_samples):
            #factor is a variable used to genrate new samples
            factor = extrapolation_factor + (j * extrapolation_factor)
            new_sample = data[i] * factor
            augmented_data.append(new_sample)
    augmented_data = np.vstack(augmented_data)
    # vstack is used to vertically stacking one array after the other
    return np.vstack((data, augmented_data))

    #output will be 30*5 +30 origanl dataset total 180 

numerical_data = df.values

# Apply data augmentation functions
augmented_data_interpolated = interpolate_data(numerical_data)
augmented_data_extrapolated = extrapolate_data(numerical_data)

# %%
# Checking the output which is an array
augmented_data_interpolated
# Out:
# array([[9.50000000e+01, 7.24000000e+02, 5.57500000e+03, ...,
#         8.00000000e+00, 5.60000000e+01, 8.80000000e+01],
#        [8.30000000e+01, 6.96000000e+02, 5.46700000e+03, ...,
#         1.20000000e+01, 4.50000000e+01, 8.60000000e+01],
#        [8.10000000e+01, 6.69000000e+02, 5.43900000e+03, ...,
#         1.00000000e+01, 3.80000000e+01, 7.90000000e+01],
#        ...,
#        [7.10000000e+01, 6.93500000e+02, 5.51450000e+03, ...,
#         5.00000000e+00, 3.85000000e+01, 9.35000000e+01],
#        [7.20000000e+01, 6.79000000e+02, 5.49533333e+03, ...,
#         5.33333333e+00, 3.93333333e+01, 9.30000000e+01],
#        [7.30000000e+01, 6.64500000e+02, 5.47616667e+03, ...,
#         5.66666667e+00, 4.01666667e+01, 9.25000000e+01]])

# %%
# Creating the datafarme from array made by interpolation
data=pd.DataFrame(augmented_data_interpolated , columns=['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
       'ERA', 'CG', 'SHO', 'SV', 'E'] )

# %%
# Checking the dataframe
data
# Out:
#         W      R           AB            H          2B         3B          HR  \
# 0    95.0  724.0  5575.000000  1497.000000  300.000000  42.000000  139.000000
# 1    83.0  696.0  5467.000000  1349.000000  277.000000  44.000000  156.000000
# 2    81.0  669.0  5439.000000  1395.000000  303.000000  29.000000  141.000000
# 3    76.0  622.0  5533.000000  1381.000000  260.000000  27.000000  136.000000
# 4    74.0  689.0  5605.000000  1515.000000  289.000000  49.000000  151.000000
# ..    ...    ...          ...          ...         ...        ...         ...
# 170  69.0  722.5  5552.833333  1453.166667  271.666667  46.833333  179.666667
# 171  70.0  708.0  5533.666667  1427.333333  269.333333  44.666667  173.333333
# 172  71.0  693.5  5514.500000  1401.500000  267.000000  42.500000  167.000000
# 173  72.0  679.0  5495.333333  1375.666667  264.666667  40.333333  160.666667
# 174  73.0  664.5  5476.166667  1349.833333  262.333333  38.166667  154.333333
#
# ...

# %%
# Creating the datafarme from array made by extrapolation
data1=pd.DataFrame(augmented_data_extrapolated, columns=['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
       'ERA', 'CG', 'SHO', 'SV', 'E'] )

# %%
# Checking the dataframe
data1
# Out:
#          W       R       AB        H      2B     3B      HR      BB      SO  \
# 0     95.0   724.0   5575.0   1497.0   300.0   42.0   139.0   383.0   973.0
# 1     83.0   696.0   5467.0   1349.0   277.0   44.0   156.0   439.0  1264.0
# 2     81.0   669.0   5439.0   1395.0   303.0   29.0   141.0   533.0  1157.0
# 3     76.0   622.0   5533.0   1381.0   260.0   27.0   136.0   404.0  1231.0
# 4     74.0   689.0   5605.0   1515.0   289.0   49.0   151.0   455.0  1259.0
# ..     ...     ...      ...      ...     ...    ...     ...     ...     ...
# 175  102.0  1105.5   8358.0   2218.5   411.0   73.5   279.0   582.0  1924.5
# 176  204.0  2211.0  16716.0   4437.0   822.0  147.0   558.0  1164.0  3849.0
# 177  306.0  3316.5  25074.0   6655.5  1233.0  220.5   837.0  1746.0  5773.5
# 178  408.0  4422.0  33432.0   8874.0  1644.0  294.0  1116.0  2328.0  7698.0
# 179  510.0  5527.5  41790.0  11092.5  2055.0  367.5  1395.0  2910.0  9622.5
#
# ...

# %%
# Concatinating both dataset to make final dataset
df1 = pd.concat([data, data1])
df1
# Out:
#          W       R       AB        H      2B     3B      HR      BB      SO  \
# 0     95.0   724.0   5575.0   1497.0   300.0   42.0   139.0   383.0   973.0
# 1     83.0   696.0   5467.0   1349.0   277.0   44.0   156.0   439.0  1264.0
# 2     81.0   669.0   5439.0   1395.0   303.0   29.0   141.0   533.0  1157.0
# 3     76.0   622.0   5533.0   1381.0   260.0   27.0   136.0   404.0  1231.0
# 4     74.0   689.0   5605.0   1515.0   289.0   49.0   151.0   455.0  1259.0
# ..     ...     ...      ...      ...     ...    ...     ...     ...     ...
# 175  102.0  1105.5   8358.0   2218.5   411.0   73.5   279.0   582.0  1924.5
# 176  204.0  2211.0  16716.0   4437.0   822.0  147.0   558.0  1164.0  3849.0
# 177  306.0  3316.5  25074.0   6655.5  1233.0  220.5   837.0  1746.0  5773.5
# 178  408.0  4422.0  33432.0   8874.0  1644.0  294.0  1116.0  2328.0  7698.0
# 179  510.0  5527.5  41790.0  11092.5  2055.0  367.5  1395.0  2910.0  9622.5
#
# ...

# %%
# Checking for duplicate as both dataframe contains original data
df1.duplicated().value_counts()
# Out:
# False    325
# True      30
# dtype: int64

# %%
# Removing the duplicate
df1 = df1.drop_duplicates()

# %%
# checking the shape of new data frame
df1.shape
# Out:
# (325, 17)

# %% [markdown]
# New dataframe have 325 row and 17 columns

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325 entries, 0 to 179
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       325 non-null    float64
#  1   R       325 non-null    float64
#  2   AB      325 non-null    float64
#  3   H       325 non-null    float64
#  4   2B      325 non-null    float64
#  5   3B      325 non-null    float64
#  6   HR      325 non-null    float64
#  7   BB      325 non-null    float64
#  8   SO      325 non-null    float64
#  9   SB      325 non-null    float64
#  10  RA      325 non-null    float64
#  11  ER      325 non-null    float64
#  12  ERA     325 non-null    float64
#  13  CG      325 non-null    float64
#  14  SHO     325 non-null    float64
#  15  SV      325 non-null    float64
#  16  E       325 non-null    float64
# dtypes: float64(17)
# memory usage: 45.7 KB

# %% [markdown]
# All feature are now float as a result of interpolation and extrapolation

# %%
df1.describe()
# Out:
#                 W            R            AB             H           2B  \
# count  325.000000   325.000000    325.000000    325.000000   325.000000
# mean   211.750769  1799.344615  14426.278462   3669.480000   718.344615
# std    186.899145  1573.026364  12505.619172   3187.913935   625.826345
# min     63.000000   573.000000   5385.000000   1324.000000   236.000000
# 25%     80.500000   678.333333   5505.000000   1383.333333   273.666667
# 50%     95.000000   751.000000   5600.000000   1488.666667   295.000000
# 75%    333.000000  2947.500000  24601.500000   6133.500000  1183.500000
# max    750.000000  6682.500000  42367.500000  11362.500000  2310.000000
#
#                3B           HR           BB            SO           SB  \
# count  325.000000   325.000000   325.000000    325.000000   325.000000
# mean    81.643077   427.981538  1228.163077   3266.372308   218.123077
# std     79.403116   386.252166  1079.607184   2849.374060   204.519033
# ...

# %% [markdown]
# From description:-
#
# 1.All column have 325 values so no missing value present.
#
# 2.The std is high for mean there might be outliers in
# - R
# - AB
# - H
# - 2B
# - 3B
# - HR
# - BB
# - SO
# - SB
# - RA
# - ERA
# - CG
# - SHO
# - SV
# - E
#
# 3.All the minimum value are value and possible
#
# 4.The difference between min,25%,50%,75% and Not normal there might be outliers.
#
# - R
# - AB
# - H
# - 2B
# - 3B
# - HR
# - BB
# - SO
# - SB
# - RA
# - ERA
# - CG
# - SHO
# - SV
# - E
#
# 5.The mean value is higher than the median (50%), hence the data is right skewed.

# %% [markdown]
# ## Graphical analysis

# %% [markdown]
# ## Univarient analysis

# %%
plt.figure(figsize=(18,18),facecolor="white")
plotnumber=1
for col in df1:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(df1[col])
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# As from above graph we can see that data is right skewed not normally distributed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['R'], bins=20, edgecolor='k')
plt.title('Histogram of R')
plt.xlabel('R')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency of R is very high near 1000, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['R'])
plt.title('Violin Plot of R')
plt.xlabel('R')
plt.show()

# %% [markdown]
# As shown in graph Frequency of R is very high near 0 -1000, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['AB'], bins=20, edgecolor='k')
plt.title('Histogram of AB')
plt.xlabel('AB')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency of AB is very high near 7000, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['AB'])
plt.title('Violin Plot of AB')
plt.xlabel('AB')
plt.show()

# %% [markdown]
# As shown in graph Frequency of AB is very high near 5000 - 10000, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['H'], bins=20, edgecolor='k')
plt.title('Histogram of H')
plt.xlabel('H')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency is very high near 2000, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['H'])
plt.title('Violin Plot of H')
plt.xlabel('H')
plt.show()

# %% [markdown]
# As shown in graph Frequency  is very high near 1000 - 4000, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['2B'], bins=20, edgecolor='k')
plt.title('Histogram of 2B')
plt.xlabel('2B')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency is very high near 300, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['2B'])
plt.title('Violin Plot of 2B')
plt.xlabel('2B')
plt.show()

# %% [markdown]
# As shown in graph Frequency of very high near 300 - 700, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['3B'], bins=20, edgecolor='k')
plt.title('Histogram of 3B')
plt.xlabel('3B')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency is very high near 40, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['3B'])
plt.title('Violin Plot of 3B')
plt.xlabel('3B')
plt.show()

# %% [markdown]
# As shown in graph Frequency of very high near 50 - 150, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['HR'], bins=20, edgecolor='k')
plt.title('Histogram of HR')
plt.xlabel('HR')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency is very high near 200, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['HR'])
plt.title('Violin Plot of HR')
plt.xlabel('HR')
plt.show()

# %% [markdown]
# As shown in graph Frequency of very high near 200 - 300, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['BB'], bins=20, edgecolor='k')
plt.title('Histogram of BB')
plt.xlabel('BB')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency is very high near 500, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['BB'])
plt.title('Violin Plot of BB')
plt.xlabel('BB')
plt.show()

# %% [markdown]
# As shown in graph Frequency of very high near 300 - 1000, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['SO'], bins=20, edgecolor='k')
plt.title('Histogram of SO')
plt.xlabel('SO')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency is very high near 2000, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['SO'])
plt.title('Violin Plot of SO')
plt.xlabel('SO')
plt.show()

# %% [markdown]
# As shown in graph Frequency of very high near 500 - 700, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['SB'], bins=20, edgecolor='k')
plt.title('Histogram of SB')
plt.xlabel('SB')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency is very high near 100, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['SB'])
plt.title('Violin Plot of SB')
plt.xlabel('SB')
plt.show()

# %% [markdown]
# As shown in graph Frequency of very high near 100 - 200, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['RA'], bins=20, edgecolor='k')
plt.title('Histogram of RA')
plt.xlabel('RA')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency is very high near 1000, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['RA'])
plt.title('Violin Plot of RA')
plt.xlabel('RA')
plt.show()

# %% [markdown]
# As shown in graph Frequency of very high near 300 - 1000, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['ERA'], bins=20, edgecolor='k')
plt.title('Histogram of ERA')
plt.xlabel('ERA')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency is very high near 5, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['ERA'])
plt.title('Violin Plot of ERA')
plt.xlabel('ERA')
plt.show()

# %% [markdown]
# As shown in graph Frequency of very high near 5 - 10, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['CG'], bins=20, edgecolor='k')
plt.title('Histogram of CG')
plt.xlabel('CG')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency is very high near 10, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['CG'])
plt.title('Violin Plot of CG')
plt.xlabel('CG')
plt.show()

# %% [markdown]
# As shown in graph Frequency of very high near 5 - 10, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['SHO'], bins=20, edgecolor='k')
plt.title('Histogram of SHO')
plt.xlabel('SHO')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency is very high near 10, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['SHO'])
plt.title('Violin Plot of SHO')
plt.xlabel('SHO')
plt.show()

# %% [markdown]
# As shown in graph Frequency of very high near 10 -30, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['SV'], bins=20, edgecolor='k')
plt.title('Histogram of SV')
plt.xlabel('SV')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency is very high near 50, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['SV'])
plt.title('Violin Plot of SV')
plt.xlabel('SV')
plt.show()

# %% [markdown]
# As shown in graph Frequency of very high near 50 - 100, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
plt.hist(df1['E'], bins=20, edgecolor='k')
plt.title('Histogram of E')
plt.xlabel('E')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Frequency is very high near 100, which indicate the data is right skewed

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x=df1['E'])
plt.title('Violin Plot of E')
plt.xlabel('E')
plt.show()

# %% [markdown]
# As shown in graph Frequency of very high near 100 - 200, which indicate the data is right skewed

# %% [markdown]
# ## Bivarient analysis

# %%
plt.figure(figsize=(18,18),facecolor="white")
plotnumber=1
for col in df1:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        sns.scatterplot(x=col, y='W',data=df1)
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From above graphs we can see that there is very high positive trends between features and labels.

# %%
plt.figure(figsize=(18,18),facecolor="white")
plotnumber=1
for col in df1:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        plt.hexbin(x=df1[col], y=df1['W'], gridsize=20, cmap='Blues')
        plt.xlabel(col,fontsize=12)
        plt.colorbar(label='Density')
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# We can see positive trends in each feature

# %% [markdown]
# ### Checking outliers

# %%
plt.figure(figsize=(15,8),facecolor="white")
plotnumber=1
for col in df1:
    if plotnumber<=17:
        ax=plt.subplot(3,6,plotnumber)
        sns.boxplot(df1[col])
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From above graph we can see that there is an outlier in 'R','3B','HR','BB','SB','SO','RA','ER','ERA','CG','SHO','SV','E'.

# %% [markdown]
# As we don't have much data so we are not going to remove the outliers instead we are going to cap them to upper threshold and continue

# %% [markdown]
# ### Treating the outliers

# %%
for column_name in df1[['R','3B','HR','BB','SB','SO','RA','ER','ERA','CG','SHO','SV','E']]:

    # Calculate the first quartile (Q1) and third quartile (Q3)
    Q1 = df1[column_name].quantile(0.25)
    Q3 = df1[column_name].quantile(0.75)

    # Calculate the interquartile range (IQR)
    IQR = Q3 - Q1

    # Calculate the upper threshold for capping (Q3 + 1.5 * IQR)
    upper_threshold = Q3 + 1.5 * IQR

    # Cap the outlier values in the specified column to the upper threshold
    df1.loc[df1[column_name] > upper_threshold, column_name] = upper_threshold

# %% [markdown]
# Checking the outliers again

# %%
plt.figure(figsize=(15,8),facecolor="white")
plotnumber=1
for col in df1:
    if plotnumber<=17:
        ax=plt.subplot(3,6,plotnumber)
        sns.boxplot(df1[col])
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### Skewness

# %%
df1.skew()
# Out:
# W      1.188421
# R      1.128055
# AB     1.089927
# H      1.099292
# 2B     1.115279
# 3B     1.253596
# HR     1.202779
# BB     1.175232
# SO     1.129192
# SB     1.202373
# RA     1.152023
# ER     1.156593
# ERA    1.160203
# CG     1.018347
# SHO    1.241906
# SV     1.203501
# E      1.175775
# dtype: float64

# %% [markdown]
# As W is the label some columns have skewness we are going to fix it later

# %% [markdown]
# ### Correlation

# %%
cor=df1.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.984617  0.981430  0.980569  0.985158  0.880699  0.963497
# R    0.984617  1.000000  0.993080  0.994259  0.994421  0.901455  0.979365
# AB   0.981430  0.993080  1.000000  0.998836  0.995869  0.916298  0.965912
# H    0.980569  0.994259  0.998836  1.000000  0.996736  0.921764  0.962997
# 2B   0.985158  0.994421  0.995869  0.996736  1.000000  0.917333  0.962915
# 3B   0.880699  0.901455  0.916298  0.921764  0.917333  1.000000  0.838792
# HR   0.963497  0.979365  0.965912  0.962997  0.962915  0.838792  1.000000
# BB   0.982619  0.985434  0.983667  0.981236  0.984822  0.867550  0.970182
# SO   0.977122  0.984428  0.992139  0.987810  0.986009  0.900639  0.970982
# SB   0.918164  0.940385  0.945857  0.950734  0.947777  0.934249  0.895977
# RA   0.946704  0.979925  0.988931  0.988416  0.980153  0.917844  0.951134
# ER   0.944558  0.978764  0.987823  0.987640  0.978579  0.919064  0.950560
# ...

# %% [markdown]
# #### Plotting the heatmap

# %%
# Visualizing the correlation matrix by plotting heatmap
mask = np.triu(np.ones_like(df1.corr(), dtype=bool))
fig, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(df1.corr(), mask=mask, cmap='inferno_r', annot=True, fmt=".1g", linewidths=0.1, ax=ax,linecolor="black")
plt.yticks(rotation=0);
plt.show()

# %% [markdown]
# As we can see data is highly correlated and we can expect it as we used mathematical formula to generate new data points.

# %%
# correlation with target variable
df1.corr().W.sort_values()
# Out:
# CG     0.641747
# 3B     0.880699
# SB     0.918164
# SHO    0.923834
# ERA    0.942382
# ER     0.944558
# RA     0.946704
# E      0.958822
# HR     0.963497
# SO     0.977122
# H      0.980569
# AB     0.981430
# BB     0.982619
# SV     0.983048
# R      0.984617
# 2B     0.985158
# W      1.000000
# Name: W, dtype: float64

# %% [markdown]
# ### Splitting the feature and label

# %%
x=df.drop('W',axis=1)
y=df.W

# %% [markdown]
# ### Treating the skewness

# %%
x= np.cbrt(x)

# %%
x.skew()
# Out:
# R      0.892970
# AB     0.168524
# H      0.642599
# 2B    -0.327033
# 3B    -0.239420
# HR     0.175310
# BB     0.018373
# SO    -0.412629
# SB     0.049734
# RA    -0.144389
# ER    -0.165952
# ERA   -0.195423
# CG    -1.043632
# SHO   -0.280283
# SV     0.325143
# E      0.719735
# dtype: float64

# %%
plt.figure(figsize=(18,18),facecolor="white")
plotnumber=1
for col in x:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(x[col])
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# after using transformation our data is normal distributed

# %% [markdown]
# ### Standardizing the dataset

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA
pca=PCA()
pca.fit_transform(x)
# Out:
# array([[ 8.87750514e-01,  2.21674096e+00, -2.72619985e+00,
#         -1.30755237e+00, -2.35409352e+00, -6.53960132e-01,
#         -1.17137669e+00, -3.63044020e-02, -4.81223964e-01,
#         -7.20812574e-01,  5.89586473e-01, -9.83169173e-02,
#          2.31781773e-01,  1.58332734e-01, -6.43972897e-02,
#         -1.67899008e-02],
#        [ 4.35097323e-02, -7.62391738e-01, -2.08097213e-01,
#         -2.44409307e-01, -1.37689625e-02,  4.31293408e-01,
#         -2.12877060e-01, -1.24550648e+00, -8.95935427e-01,
#          1.38962809e-01, -6.93931964e-01,  1.15406058e-01,
#          4.89454891e-01,  4.84635577e-01,  4.65651957e-02,
#          3.53555315e-02],
#        [-1.14943235e+00,  8.80807512e-01,  2.15348587e-01,
#         -2.45456347e+00,  6.80504028e-01, -2.62617301e-01,
#         -1.29427024e+00,  1.41666608e-01,  3.34714293e-02,
#          1.21838927e+00, -1.50101583e-01,  2.20094816e-01,
#          7.70436681e-02, -2.52630560e-01,  2.39721374e-03,
#         -1.86567565e-04],
# ...

# %% [markdown]
# ### Scree plot

# %%
plt.figure(figsize=(20,20))
plt.plot(np.cumsum(pca.explained_variance_ratio_)) # np.cumsum is for cumulative of all.
plt.xlabel('Principal Component')
plt.grid('both')
plt.yticks(np.arange(0.5,1.03,0.03))
plt.xticks(range(1,32,2))
plt.ylabel('Variance covered')
plt.title("PCA")
plt.show()

# %% [markdown]
# Around 10 PC are able to explain 98% variance.

# %%
pca=PCA(n_components=10)
new_pcom=pca.fit_transform(x)

# %%
princi_comp=pd.DataFrame(new_pcom,columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10'])
princi_comp
# Out:
#          PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0   0.887751  2.216741 -2.726200 -1.307552 -2.354094 -0.653960 -1.171377
# 1   0.043510 -0.762392 -0.208097 -0.244409 -0.013769  0.431293 -0.212877
# 2  -1.149432  0.880808  0.215349 -2.454563  0.680504 -0.262617 -1.294270
# 3   0.859764 -1.476804 -0.232782 -0.537044  0.636222 -0.947308  0.239016
# 4   3.238947  1.515419  0.157461 -0.919717  0.717880  0.638923  1.019958
# 5  -0.730892  3.816561  3.136025 -0.849052 -0.943506 -0.030086 -0.059582
# 6  -0.113455  0.786583  2.551597  0.913199 -1.674171 -1.053686 -0.771242
# 7  -0.734748 -2.266956  1.477348  1.269773 -2.684449  1.152465  1.519262
# 8  -1.325173 -0.516424 -1.295372  0.972896 -0.370149  0.135024 -0.840958
# 9   2.046293  2.139401  0.337837 -0.282681 -0.731842 -0.893550  1.094281
# 10  1.083737  1.101689  0.800960  0.811535  0.764005 -0.942655 -0.802212
# 11 -1.962821  0.818568  1.308917  0.571017  0.856776  2.052572 -0.975786
# ...

# %%
x=princi_comp

# %%
# Checking the correlation
cor=x.corr()
cor
# Out:
#                PC1           PC2           PC3           PC4           PC5  \
# PC1   1.000000e+00  2.261481e-16  9.096063e-17  4.538271e-16 -6.358802e-16
# PC2   2.261481e-16  1.000000e+00 -1.679694e-16 -1.799877e-16  3.667047e-17
# PC3   9.096063e-17 -1.679694e-16  1.000000e+00  3.073796e-16 -6.371779e-16
# PC4   4.538271e-16 -1.799877e-16  3.073796e-16  1.000000e+00  4.500262e-16
# PC5  -6.358802e-16  3.667047e-17 -6.371779e-16  4.500262e-16  1.000000e+00
# PC6  -6.930666e-18 -1.345461e-16  1.705337e-16 -2.053306e-16 -3.068041e-16
# PC7   8.648728e-18 -2.730066e-17  3.755431e-17  7.606844e-17 -1.767040e-16
# PC8   5.434720e-17 -1.944266e-16  3.933086e-17 -6.708796e-17 -1.586256e-16
# PC9  -5.091533e-17  6.589513e-17  1.105417e-17  2.804750e-16 -2.476814e-16
# PC10  1.594253e-16  1.547474e-17  9.806918e-17 -1.361609e-16  2.072621e-16
#
#                PC6           PC7           PC8           PC9          PC10
# ...

# %%
# Visualizing the correlation matrix by plotting heatmap
mask = np.triu(np.ones_like(x.corr(), dtype=bool))
fig, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(x.corr(), mask=mask, cmap='inferno_r', annot=True, fmt=".1g", linewidths=0.1, ax=ax,linecolor="black")
plt.yticks(rotation=0);
plt.show()

# %% [markdown]
# From the above heatmap we can see the data is no more correlated as we perform PCA we made new dataframe which is not correlated anymore

# %% [markdown]
# ## Feature selection

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
best_features = SelectKBest(score_func=f_classif,k=8) # run multiple time and find the best

fit=best_features.fit(x,y)

df_scores=pd.DataFrame(fit.scores_)

df_columns=pd.DataFrame(x.columns)

# concatenate dataframe
feature_scores=pd.concat([df_columns,df_scores],axis=1)

feature_scores.columns=['Feature_Name','Score'] # name output columns
print(feature_scores.nlargest(10,'Score')) # print 25 best features
# Out:
#   Feature_Name     Score
# 2          PC3  2.547288
# 0          PC1  2.392373
# 5          PC6  1.600019
# 9         PC10  1.384334
# 8          PC9  1.352944
# 1          PC2  1.292588
# 4          PC5  0.817932
# 3          PC4  0.776237
# 7          PC8  0.764496
# 6          PC7  0.217898

# %% [markdown]
# As we can see there is drastic difference between PC8 and PC7 so 10 feature are to be selected

# %% [markdown]
# # Model building

# %%
# importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## finding the best Random state

# %%
random_states = range(1, 200)
r2_scores = []

for rs in random_states:
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=rs)
    LR = LinearRegression()
    LR.fit(x_train, y_train)
    pred = LR.predict(x_test)
    r2 = r2_score(y_test, pred)
    r2_scores.append(r2)

max_r2 = max(r2_scores)
max_rs = random_states[r2_scores.index(max_r2)]

print("Best accuracy is", max_r2, "at random_state", max_rs)
# Out:
# Best accuracy is 0.9149251873488391 at random_state 39

# %% [markdown]
# ## Train test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.40, random_state=max_rs)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor

# %%
training_r2_score = []
testing_r2_score = []

# %%
def model_prediction(model):
    model.fit(x_train,y_train)
    y_pred = model.predict(x_train)
    pred = model.predict(x_test)
    a = r2_score(y_train,y_pred)*100
    b = r2_score(y_test,pred)*100
    training_r2_score.append(a)
    testing_r2_score.append(b)
    print(f"R2_Score of {model} model on Training Data is:",a)
    print(f"R2_Score of {model} model on Testing Data is:",b)
    print("\n------------------------------------------------------------------------")
    print(f"Mean Absolute Error of {model} model is:",mean_absolute_error(y_test,pred))
    print(f"Mean Square Error of {model} model is:", mean_squared_error(y_test,pred))
    print(f"Squarroot Mean Square Error  {model} model is:",np.sqrt(mean_squared_error(y_test,pred)))
    print("\n------------------------------------------------------------------------")

# %%
model_prediction(LinearRegression())
# Out:
# R2_Score of LinearRegression() model on Training Data is: 85.78607098033515
# R2_Score of LinearRegression() model on Testing Data is: 91.49251873488392
#
# ------------------------------------------------------------------------
# Mean Absolute Error of LinearRegression() model is: 2.7476528851059165
# Mean Square Error of LinearRegression() model is: 10.456521591061778
# Squarroot Mean Square Error  LinearRegression() model is: 3.233654525619856
#
# ------------------------------------------------------------------------

# %%
lasscv=LassoCV(alphas=None,max_iter=10)
lasscv.fit(x_train,y_train)
# Out:
# LassoCV(max_iter=10)

# %%
alpha=lasscv.alpha_
alpha
# Out:
# 1.2373256658071

# %%
model_prediction(Lasso(alpha))
# Out:
# R2_Score of Lasso(alpha=1.2373256658071) model on Training Data is: 78.90508120026954
# R2_Score of Lasso(alpha=1.2373256658071) model on Testing Data is: 82.52769853922311
#
# ------------------------------------------------------------------------
# Mean Absolute Error of Lasso(alpha=1.2373256658071) model is: 3.9322047451078426
# Mean Square Error of Lasso(alpha=1.2373256658071) model is: 21.475157191270142
# Squarroot Mean Square Error  Lasso(alpha=1.2373256658071) model is: 4.63412960449642
#
# ------------------------------------------------------------------------

# %%
ridgecv=RidgeCV(alphas=np.arange(0.001,0.1,0.01))
ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]))

# %%
model_prediction(Ridge(alpha=ridgecv.alpha_))
# Out:
# R2_Score of Ridge(alpha=0.09099999999999998) model on Training Data is: 85.78487171291148
# R2_Score of Ridge(alpha=0.09099999999999998) model on Testing Data is: 91.5399782183297
#
# ------------------------------------------------------------------------
# Mean Absolute Error of Ridge(alpha=0.09099999999999998) model is: 2.7369719460991173
# Mean Square Error of Ridge(alpha=0.09099999999999998) model is: 10.398189271790457
# Squarroot Mean Square Error  Ridge(alpha=0.09099999999999998) model is: 3.2246223456073824
#
# ------------------------------------------------------------------------

# %%
model_prediction(SVR())
# Out:
# R2_Score of SVR() model on Training Data is: 22.432972615319414
# R2_Score of SVR() model on Testing Data is: 12.05887386844271
#
# ------------------------------------------------------------------------
# Mean Absolute Error of SVR() model is: 8.542148124363495
# Mean Square Error of SVR() model is: 108.08819384739114
# Squarroot Mean Square Error  SVR() model is: 10.396547207962417
#
# ------------------------------------------------------------------------

# %%
model_prediction(RandomForestRegressor())
# Out:
# R2_Score of RandomForestRegressor() model on Training Data is: 88.09667214191852
# R2_Score of RandomForestRegressor() model on Testing Data is: 51.97135431380304
#
# ------------------------------------------------------------------------
# Mean Absolute Error of RandomForestRegressor() model is: 7.194166666666667
# Mean Square Error of RandomForestRegressor() model is: 59.03187499999999
# Squarroot Mean Square Error  RandomForestRegressor() model is: 7.683220353471583
#
# ------------------------------------------------------------------------

# %%
model_prediction(GradientBoostingRegressor())
# Out:
# R2_Score of GradientBoostingRegressor() model on Training Data is: 99.99999856292291
# R2_Score of GradientBoostingRegressor() model on Testing Data is: 57.05264348025314
#
# ------------------------------------------------------------------------
# Mean Absolute Error of GradientBoostingRegressor() model is: 6.900382895491795
# Mean Square Error of GradientBoostingRegressor() model is: 52.786476600208296
# Squarroot Mean Square Error  GradientBoostingRegressor() model is: 7.265430241920178
#
# ------------------------------------------------------------------------

# %%
model_prediction(DecisionTreeRegressor())
# Out:
# R2_Score of DecisionTreeRegressor() model on Training Data is: 100.0
# R2_Score of DecisionTreeRegressor() model on Testing Data is: 50.30227696480027
#
# ------------------------------------------------------------------------
# Mean Absolute Error of DecisionTreeRegressor() model is: 6.916666666666667
# Mean Square Error of DecisionTreeRegressor() model is: 61.083333333333336
# Squarroot Mean Square Error  DecisionTreeRegressor() model is: 7.815582725128904
#
# ------------------------------------------------------------------------

# %%
model_prediction(KNeighborsRegressor())
# Out:
# R2_Score of KNeighborsRegressor() model on Training Data is: 60.77608409986861
# R2_Score of KNeighborsRegressor() model on Testing Data is: 63.629131589355325
#
# ------------------------------------------------------------------------
# Mean Absolute Error of KNeighborsRegressor() model is: 5.816666666666666
# Mean Square Error of KNeighborsRegressor() model is: 44.70333333333334
# Squarroot Mean Square Error  KNeighborsRegressor() model is: 6.686055139866358
#
# ------------------------------------------------------------------------

# %%
model_prediction(AdaBoostRegressor())
# Out:
# R2_Score of AdaBoostRegressor() model on Training Data is: 99.17917780340343
# R2_Score of AdaBoostRegressor() model on Testing Data is: 62.162061886735586
#
# ------------------------------------------------------------------------
# Mean Absolute Error of AdaBoostRegressor() model is: 6.195833333333334
# Mean Square Error of AdaBoostRegressor() model is: 46.50650462962963
# Squarroot Mean Square Error  AdaBoostRegressor() model is: 6.819567774399609
#
# ------------------------------------------------------------------------

# %%
model_prediction(XGBRegressor ())
# Out:
# R2_Score of XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...) model on Training Data is: 99.99999974171402
# R2_Score of XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
# ...

# %%
models=['LinearRegression','Lasso','Ridge','SVR','RandomForestRegressor','GradientBoostingRegressor','DecisionTreeRegressor','KNeighborsRegressor','AdaBoostRegressor','XGBRegressor']

# %%
df1 = pd.DataFrame({"Algorithms":models,
                   "Training R2 Score":training_r2_score,
                   "Testing R2 Score":testing_r2_score
                  })
df1
# Out:
#                   Algorithms  Training R2 Score  Testing R2 Score
# 0           LinearRegression          85.786071         91.492519
# 1                      Lasso          78.905081         82.527699
# 2                      Ridge          85.784872         91.539978
# 3                        SVR          22.432973         12.058874
# 4      RandomForestRegressor          88.096672         51.971354
# 5  GradientBoostingRegressor          99.999999         57.052643
# 6      DecisionTreeRegressor         100.000000         50.302277
# 7        KNeighborsRegressor          60.776084         63.629132
# 8          AdaBoostRegressor          99.179178         62.162062
# 9               XGBRegressor         100.000000         61.089803

# %%
df1.plot(x="Algorithms",y=["Training R2 Score","Testing R2 Score"], figsize=(16,6),kind="bar",
        title="Performance Visualization of Different Models",colormap="Set1")
plt.yticks(range(60,106,5))
plt.show()

# %% [markdown]
# ## Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Checking the Best CV value

# %%
num_folds_range = range(2,20)

model = LinearRegression()

fold_performance = {}

for num_folds in num_folds_range:
    scores = cross_val_score(model, x, y, cv=num_folds, scoring='neg_mean_squared_error')  # or 'r2' for coefficient of determination
    fold_performance[num_folds] = {
        'mean': np.mean(scores),
        'std': np.std(scores)
    }
    
df_fold_performance = pd.DataFrame(fold_performance).transpose()

print(df_fold_performance)
# Out:
#           mean         std
# 2  -236.582143  160.896501
# 3   -32.172969   15.838779
# 4   -27.480664   14.709444
# 5   -28.238209   20.667630
# 6   -35.633863   24.079969
# 7   -31.959756   28.980182
# 8   -28.145204   25.783618
# 9   -37.700751   44.288669
# 10  -37.202764   42.418263
# 11  -34.281705   41.496586
# 12  -33.193770   40.274045
# 13  -34.945997   46.563387
# 14  -34.715001   46.534187
# 15  -33.254018   45.246145
# 16  -31.362462   44.435578
# 17  -29.606842   43.673959
# 18  -27.989358   42.964414
# 19  -26.903505   42.138742

# %% [markdown]
# cv value 4 is best tradeoff

# %%
# checking cv score for logistic Regression
score = cross_val_score(LinearRegression(),x,y,cv=4)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[0]/100)- score.mean())
# Out:
# [0.64874492 0.47519173 0.75093881 0.90345212]
# 0.6945818927959881
# Differnet between Accuracy score and cross validation score is-  0.22034329455285107

# %%
# checking cv score for logistic Regression
score = cross_val_score(Lasso(),x,y,cv=4)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[1]/100)- score.mean())
# Out:
# [0.26322031 0.65783461 0.76353984 0.93192135]
# 0.6541290279508805
# Differnet between Accuracy score and cross validation score is-  0.17114795744135058

# %%
# checking cv score for logistic Regression
score = cross_val_score(Ridge(),x,y,cv=4)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[2]/100)- score.mean())
# Out:
# [0.67024641 0.55676206 0.7671675  0.93348599]
# 0.7319154904196465
# Differnet between Accuracy score and cross validation score is-  0.18348429176365044

# %%
# checking cv score for logistic Regression
score = cross_val_score(SVR(),x,y,cv=4)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[3]/100)- score.mean())
# Out:
# [-0.30256149  0.07722658  0.12101695 -0.25205849]
# -0.08909411161684783
# Differnet between Accuracy score and cross validation score is-  0.20968285030127493

# %%
# checking cv score for logistic Regression
score = cross_val_score(RandomForestRegressor(),x,y,cv=4)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[4]/100)- score.mean())
# Out:
# [-0.21363405  0.28774853  0.52534965  0.39165477]
# 0.2477797254078979
# Differnet between Accuracy score and cross validation score is-  0.27193381773013253

# %%
# checking cv score for logistic Regression
score = cross_val_score(GradientBoostingRegressor(),x,y,cv=4)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[5]/100)- score.mean())
# Out:
# [-0.3007745   0.46523126  0.74701639  0.15853504]
# 0.26750205092685575
# Differnet between Accuracy score and cross validation score is-  0.30302438387567565

# %%
# checking cv score for logistic Regression
score = cross_val_score(DecisionTreeRegressor(),x,y,cv=4)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[6]/100)- score.mean())
# Out:
# [-0.70012706 -0.06487872  0.04108434 -0.35368561]
# -0.2694017655969544
# Differnet between Accuracy score and cross validation score is-  0.7724245352449571

# %%
# checking cv score for logistic Regression
score = cross_val_score(KNeighborsRegressor(),x,y,cv=4)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[7]/100)- score.mean())
# Out:
# [-0.0041169   0.52855058  0.5765253   0.70215808]
# 0.4507792662576166
# Differnet between Accuracy score and cross validation score is-  0.18551204963593665

# %%
# checking cv score for logistic Regression
score = cross_val_score(AdaBoostRegressor(),x,y,cv=4)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[8]/100)- score.mean())
# Out:
# [-0.16641536  0.46826179  0.71775918  0.20166889]
# 0.30531862394456055
# Differnet between Accuracy score and cross validation score is-  0.3163019949227953

# %%
# checking cv score for logistic Regression
score = cross_val_score(XGBRegressor(),x,y,cv=4)
print(score)
print(score.mean())
print("Differnet between Accuracy score and cross validation score is- ", (testing_r2_score[9]/100)- score.mean())
# Out:
# [0.31560261 0.41591444 0.25938929 0.58116308]
# 0.3930173558285337
# Differnet between Accuracy score and cross validation score is-  0.2178806704472469

# %% [markdown]
# Lasso and ridge have least difference between CV score and accuracy

# %% [markdown]
# ## Hyperperameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Lasso

# %%
model1=Lasso()

# %%
param_grid={'alpha':[0.005,0.01,0.02],
           'max_iter':[500,750,1000],
           'selection':['cyclic', 'random'],
           'random_state':[30,40,50]}

# %%
grid_search = GridSearchCV(model1, param_grid=param_grid, cv=4)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=4, estimator=Lasso(),
#              param_grid={'alpha': [0.005, 0.01, 0.02],
#                          'max_iter': [500, 750, 1000],
#                          'random_state': [30, 40, 50],
#                          'selection': ['cyclic', 'random']})

# %%
grid_search.best_estimator_
best=grid_search.best_params_
best
# Out:
# {'alpha': 0.02, 'max_iter': 500, 'random_state': 50, 'selection': 'random'}

# %%
model_prediction(Lasso(alpha= 0.02, max_iter= 500, random_state= 50, selection= 'random'))
# Out:
# R2_Score of Lasso(alpha=0.02, max_iter=500, random_state=50, selection='random') model on Training Data is: 85.77812286472664
# R2_Score of Lasso(alpha=0.02, max_iter=500, random_state=50, selection='random') model on Testing Data is: 91.68182564711216
#
# ------------------------------------------------------------------------
# Mean Absolute Error of Lasso(alpha=0.02, max_iter=500, random_state=50, selection='random') model is: 2.7005985693853116
# Mean Square Error of Lasso(alpha=0.02, max_iter=500, random_state=50, selection='random') model is: 10.22384499109456
# Squarroot Mean Square Error  Lasso(alpha=0.02, max_iter=500, random_state=50, selection='random') model is: 3.1974747834962765
#
# ------------------------------------------------------------------------

# %% [markdown]
# ### Ridge

# %%
model2=Ridge()

# %%
param_grid={'alpha':[0.005,0.01,0.02],
           'max_iter':[500,750,1000],
           'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs'],
           'random_state':[30,40,50]}

# %%
grid_search = GridSearchCV(model2, param_grid=param_grid, cv=4)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=4, estimator=Ridge(),
#              param_grid={'alpha': [0.005, 0.01, 0.02],
#                          'max_iter': [500, 750, 1000],
#                          'random_state': [30, 40, 50],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag', 'saga', 'lbfgs']})

# %%
grid_search.best_estimator_
best=grid_search.best_params_
best
# Out:
# {'alpha': 0.02, 'max_iter': 500, 'random_state': 40, 'solver': 'saga'}

# %%
model_prediction(Ridge(alpha= 0.02, max_iter= 500, random_state= 40, solver = 'saga'))
# Out:
# R2_Score of Ridge(alpha=0.02, max_iter=500, random_state=40, solver='saga') model on Training Data is: 85.78600176693499
# R2_Score of Ridge(alpha=0.02, max_iter=500, random_state=40, solver='saga') model on Testing Data is: 91.46637950797847
#
# ------------------------------------------------------------------------
# Mean Absolute Error of Ridge(alpha=0.02, max_iter=500, random_state=40, solver='saga') model is: 2.7524524240274473
# Mean Square Error of Ridge(alpha=0.02, max_iter=500, random_state=40, solver='saga') model is: 10.488649242242303
# Squarroot Mean Square Error  Ridge(alpha=0.02, max_iter=500, random_state=40, solver='saga') model is: 3.238618415658489
#
# ------------------------------------------------------------------------

# %%
m=Lasso(alpha= 0.02, max_iter= 500, random_state= 50, selection= 'random')
m.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.02, max_iter=500, random_state=50, selection='random')

# %% [markdown]
# ## Saving the best model

# %%
import pickle
filename='Basball.pkl'
pickle.dump(m,open(filename,'wb'))#saved model

# %% [markdown]
# ## Loading the model

# %%
loaded_model=pickle.load(open('Basball.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 91.68182564711216

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=['Predicted','Original'])
conclusion
# Out:
#                   0          1         2          3          4          5   \
# Predicted  63.709962  81.906517  79.03866  83.911594  73.512304  89.959084
# Original   63.000000  88.000000  81.00000  81.000000  68.000000  93.000000
#
#                   6           7         8         9          10         11
# Predicted  66.166747  103.558461  91.13022  67.27303  85.541447  80.647673
# Original   67.000000  100.000000  92.00000  71.00000  84.000000  79.000000
